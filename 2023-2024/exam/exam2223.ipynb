# %% [markdown]
# <h1><center><strong><font color="Teal">EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> <font color="red">Exam 😤💪</font></font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <br/>
# Year 2022-2023
#
# Original Content
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Exam Rules / Règles de l'examen**</font>

# %% [markdown]
# Here are the rules and information you need for this exam:
# - duration: 2 hours
# - communication in anyway is forbidden and will yield 0 / 20
# - graduation: 70% of your final grade are dedicated to this exam
# - you can leave the room during the last 30 minutes
# - how to give your file: upload your file starting from the last 30 minutes on the dedicated Arche secion named "Exam"
#
# 🇫🇷 Les règes et informations que vous devez savoir pour cet examen sont les suivantes :
# - durée : 2 heures
# - communication interdite sous toutes ses formes (sous peine de 0 / 20)
# - note : cet exam compte pour 70 % de la note finale
# - vous pouvez quitter la salle à partir de la dernière demi-heure
# - rendre son travail : téléversez vos fichiers dans la section dédiée sur Arche (section "Exam"). Le téléversement s'ouvre automatiquement pendant la dernière demi-heure.

# %% [markdown]
# # <font color="teal">**Part 1: some classic exercises (Difficulty 🌶) / Partie 1: quelques exercices (Difficulté 🌶)**</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!** 🌶

# %% [markdown]
# We are the 16/01/2023 (in the French format).
#
# Create three **integer** variables:
# 1. one which contains the current day
# 2. one which contains this month
# 3. one which contains the current year
#
# 🇫🇷 Nous sommes le 16/01/2023.
#
# Créez trois variables d'entier (**integer**) :
# 1. une contenant le jour actuel
# 2. une contenant le mois
# 3. une dernière contenant l'année en cours

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Using the three previous variables, create a `date` variable which contains the date in this format `16/01/2023`
#
# To pad the month with a zero you should use
# ```python
# '{:0>2}'.format(mynumber)
# ```
#
# 🇫🇷 À l'aide des trois variables que vous venez de créer, créez une variable `date` contenant la date dans le format suivant `16/01/2023`
#
# Pour préfixer le mois avec un zéro, vous devriez utiliser
# ```python
# '{:0>2}'.format(monnombre)
# ```

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# 16/01/2023

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Create a variable named `me` which contains information about who you are:
# - firstname
# - lastname
# - your master's name (cognitive sciences or natural language processing)
#
# Use the type you feel is the most appropriate for this.
#
# 🇫🇷 Créez une variable nommée `moi` qui contient des informations personnelles :
# - prénom
# - nom
# - le nom de votre master (Sciences co ou TAL)
#
# Pour ce faire, utilisez le type qui vous semble le plus approprié.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Save the variable `me` into a file. Then print a success message such as "Save successful".
#
# 🇫🇷 Sauvegardez la variable `moi` dans un fichier. Ensuite, affichez un message de réussite de l'opération. Par exemple : "Enregistrement réussi"

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# Save successful

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Given the following list, extract two lists using Python:
# - one which only contains fruits
# - one which only contains animals
#
# Then print the number of fruits and the number of animals.
#
# (FYI Sonny Boy Williamson was a famous singer, an artist, and a magnificent harmonica master 🎵)
#
# 🇫🇷 En considérant la liste suivante, extrayez-en deux listes à l'aide de Python :
# - une liste qui contient uniquement les fruits
# - une liste qui contient uniquement les animaux
#
# Ensuite affichez le nombre de fruits et le nombre d'animaux.
#
# (Pour info, Sonny Boy Williamson fut un musicien de renom, un artiste connu pour sa maîtrise de l'harmonica 🎵)

# %%
elements = ['litchi', 'mango', 'puppy', 'doggy', 'kitty', 'cat', 'tiger', 'watermelon', 'Sonny Boy Williamson']
## Version française : 
# elements = ['litchi', 'mangue', 'chiot', 'chien', 'chaton', 'chat', 'tigre', 'pastèque', 'Sonny Boy Williamson']

# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# # <font color="teal">**Part 2: Harry Potter (Difficulty / Difficulté 🌶🌶)**</font>

# %% [markdown]
# <img height="200px" src="data:image/png;base64,..." />

# %% [markdown]
# Let's explore some Harry Potter information.
#
# Harry Potter is a famous eponym novel for children written by J.K Rowling. It takes place in an alternative world of magicians and a school of sorcerers.
#
# 🇫🇷 Utilisons désormais des informations issues d'Harry Potter.
#
# Harry Potter est un roman éponyme pour enfants. Il fut écrit par J.K. Rowling et prend part dans un monde alternatif où magiciens et écoles de magiciens sont ordinaires.

# %% [markdown]
# Let's start by downloading the files. (Ask me if you encounter any issue to do so)
#
# 🇫🇷 Commonçons par télécharger les fichiers. (N'hésitez pas à me demander si vous rencontrez le moindre problème à ce stade)

# %%
## Download the dataset (can also be manually downloaded here: https://gitlab.com/gguibon/idmc-storage)
## Ces commandes téléchargent les fichiers. Ils peuvent aussi être téléchargés manuellement ici https://gitlab.com/gguibon/idmc-storage: 

## using the wget python library works eerywhere
## cette méthode marche sous tous les systèmes d'exploitation
! pip install wget
import wget
wget.download("https://gitlab.com/gguibon/idmc-storage/-/raw/main/characters.json")
wget.download("https://gitlab.com/gguibon/idmc-storage/-/raw/main/spells.json")

## unix commands are also available but not on Windows
## ces commandes unix sont aussi disponibles mais pas sous Windows
# ! wget https://gitlab.com/gguibon/idmc-storage/-/raw/main/characters.json
# ! wget https://gitlab.com/gguibon/idmc-storage/-/raw/main/spells.json

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Using the two files, print the number of characters and the number of spells
#
# 🇫🇷 À partir de ces deux fichiers, affichez le nombre de personnages (*characters*) et de sorts (*spells*)

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# There are 140 characters and 301 spells

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶

# %% [markdown]
# Get the list of student names. Then print this list along with the number of students.
#
# Tip 💡:
# - There should be 53 students 😉
#
# 🇫🇷 Récupérez la liste des noms d'étudiants. Ensuite affichez cette liste aux côtés du nombre total d'étudiants.
#
# Astuce 💡:
# - Il devrait y avoir 53 étudiants 😉

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Sort this list of students in alphabetic order, the print it.
#
# 🇫🇷 Triez la list des étudiants par ordre alphabétique, puis affichez la.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# ['Albus Severus Potter', 'Alicia Spinnet', 'Angelina Johnson', 'Anthony Goldstein', 'Blaise Zabini', 'Cedric Diggory', 'Cho Chang', 'Colin Creevey', 'Cormac McLaggen', 'Dean Thomas', 'Dennis Creevey', 'Draco Malfoy', 'Edward Remus Lupin', 'Ernest Macmillan', 'Fred Weasley', 'George Weasley', 'Ginevra (Ginny) Molly Weasley', 'Graham Montague', 'Gregory Goyle', 'Hannah Abbott', 'Harry James Potter', 'Hermione Jean Granger', 'James Sirius Potter', 'Justin Finch-Fletchley', 'Katie Bell', 'Lavender Brown', 'Lee Jordan\xa0', 'Luna Lovegood', 'Marcus Belby', 'Marcus Flint', 'Marietta Edgecombe', 'Michael Corner', 'Millicent Bulstrode', 'Myrtle Elizabeth Warren (Moaning Myrtle)', 'Neville Longbottom', 'Oliver Wood', 'Padma Patil', 'Pansy Parkinson', 'Parvati Patil', 'Penelope Clearwater', 'Percy Ignatius Weasley', 'Roger Davies', 'Romilda Vane', 'Ronald Bilius Weasley', 'Rose Granger-Weasley', 'Scorpius Hyperion Malfoy', 'Seamus Finnigan', 'Susan Bones', 'Terry Boot', 'Theodore Nott', 'Tom Marvolo Riddle', 'Vincent Crabbe', 'Zacharias Smith']

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶

# %% [markdown]
# Create a function to find a character by their id.
#
# 🇫🇷 Créez une fonction pour trouver un personnage (*character*) par leur identifiant (*id*)

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Use this function to find the character whom id is `84` and save its information into a JSON file named `84.json`. (What an original name! 😀)
#
# 🇫🇷 Utilisez cette fonction que vous venez de créer pour trouver le personnage qui a l'identifiant `84`. Sauvegardez cette information dans un fichier JSON nommé `84.json`. (En voici un nom original 😀)

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶  🌶

# %% [markdown]
# Create a function to retrieve all the characters of a the same family (using their lastname).
#
# 🇫🇷 Créez une fonction pour récupérer tous les personnages d'une même famille, à l'aide de leur nom de famille.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Use this function to get all the characters from the Potter family. Then save them into one JSON file named `potters.json`.
#
# 🇫🇷 Utilisez cette fonction pour obtenir tous les personnages de la famille Potter. Puis enregistrez les dans un fichier JSON nommé `potters.json`.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# How many Potter members are there?
#
# 🇫🇷 Combien de membres y a-t-il dans la famille Potter ?

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶 🌶

# %% [markdown]
# There are four main houses in Hogwarts along with two other magic schools (Beauxbatons -- the French one -- and Durmstrang).
#
# Get the number of character per House.
#
# 🇫🇷 Il y a quatre maisons principales dans Poudlard (*Hogwarts* en anglais). Les maisons sont ici considérées comme des groupes de dortoir. En plus de ces quatres maisons principales, deux autres écoles de magie sont présentes (Beauxbatons - une école de magie française - et Durmstrang).
#
# Obtenez le nombre de personnage poour chaque maison.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# # <font color="teal">**Part 3: Spells / Sorts (Difficulty / Difficulté 🌶🌶🌶)**</font>

# %% [markdown]
# Now let's also consider the spells 🧙.
#
# 🇫🇷 Considérons maintenant les sorts 🧙.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶  🌶

# %% [markdown]
# Create a class named `SpellDataset` which possesses the following methods:
# - a method to get the number of spells of a specific type
# - a method to retrieve the different spell types
# - a method to get a random spell of a specific type
#
# 🇫🇷 Créez une classe nommée `DonneesDesSorts` ou `SpellDataset` qui possède les méthodes suivantes :
# - une méthode pour obtenir le nombre de sorts d'un type spécifique
# - une méthode pour récupérer les différents types de sorts
# - une méthode pour récupérer un sort aléatoire d'un type spécifique

# %%
import random 

# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶

# %% [markdown]
# Use this `SpellDataset` to print:
# - the list of different types of spells
# - a random spell of type "healing spell"
#
# 🇫🇷 Utilisez votre classe `SpellDataset` (ou `DonneesDesSorts`)  pour afficher :
# - la liste des différents types de sorts
# - un sort aléatoire du type "healing spell" (ce qui signifie un sort de soin)

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# ['curse', 'counter-jinx', 'dark charm', 'transformation', 'transportation', 'hex', 'transfiguration', 'charm', 'transfiguration spell', 'dark arts', 'counter-charm', 'untransfiguration', 'conjuration', 'patented charm', 'jinx', 'transfiguration jinx', 'spell', 'vanishment', 'healing spell', 'counter-spell', 'counter-curse']
# {'Name': 'Bandaging Charm', 'Incantation': 'Ferula', 'Effect': 'Bandages target', 'Light': None, 'Types': ['healing spell', 'charm', 'conjuration']}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶 🌶

# %% [markdown]
# Create a class to represent a `Character` with the following attributes:
# - name
# - job
# - gender
# - house
# - skills
# - a spell_type from the list of different types using your `SpellDataset` class instance
#
# And the following methods:
# - `launchRandomSpell` to make the character use a random spell. It should only print the name of the character associated with the `Effect` of the spell.
#
# Of course, a character can only use spells of the same type!
#
# 🇫🇷 Créez une classe pour représenter un `Personnage` (ou `Character` en anglais) avec les attributs suivants :
# - nom (*name*)
# - travail (*job*)
# - gender (*genre*)
# - house (*maison*)
# - compétences (*skills*)
# - un type de sort (*spell_type*) issu de la liste des différents types de sorts obtenue à l'aide de votre instance de classe `SpellDataset` ou `DonneesDesSorts`)

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶

# %% [markdown]
# Create a new instance of the `Character` class for the character named "Katie Bell". Give her the "curse" spell type.
#
# Then make `Katie Bell` launch a Random Spell.
#
# 🇫🇷 Créez une nouvelle instance de la classe `Personnage` (ou `Character`) nommée "Katie Bell". Donnez-lui le type de sort "maudite" (ou "curse" en anglais).
#
# Ensuite, faites en sorte que `Katie Bell` jette un sort aléatoire.

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# Tortures, possibly by transfiguring the target to death

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**  🌶 🌶

# %% [markdown]
# Finally, the last exercise! Create yourself as a character using the `Character` class.
#
# Print yourself as a dictionary and launch a random spell! 🧙
#
# 🇫🇷 Dernier exercice ! Créez vous, vous-même, en tant que personnage à l'aide de la classe `Personnage`(ou `Character`).
#
# Affichez votre instance en tant que dictionnaire et lancez un sort aléatoire ! 🧙

# %%
# CODE ME PRETTY PLEASE 🥺
# code moi steuplé 🥺
# Out:
# {'name': 'Gaël Guibon', 'job': 'Associate Professor', 'gender': 'Male', 'house': 'Beauxbatons', 'skills': 'Teleportation', 'spell_type': 'transportation'}
# Magically transports the caster
