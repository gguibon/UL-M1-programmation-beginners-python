# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 1</font></strong></center></h1>
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im) and [Mathieu d'Acquin](https://mdaquin.github.io/)'s Course
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Student Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.
#
# Please send your completed code as a .ipynb or .py file (without errors in Python3) **to Gaël Guibon (gael.guibon@univ-lorraine.fr) by 5pm Thursday next week**. This one won't be marked, it is just to test your understanding. If you want to comment on the questions, ask your own questions or explain your answers, don't hesitate to use the text-boxes in Jupyter Notebook or comments in the code.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The main objective of this lab is to ensure you start coding in Python and are confortable with one of the main advantages of the interpeter, namely, the notebooks (Jupyter Notebook, Jupyter Lab, VSCode notebooks, Google Colab, etc.).
# Hence this lab seek to:
# 1. give you basic understanding of the Python's know-how
# 2. make you confortable with notebooks
#
# ### <font color="teal">Organization</font>
#
# First a set of reminders
# 1. Reminders of some basics
#
# Followed by basics with exercices
#
# 2. Instructions
# 3. Variables
# 4. Variable names conventions
# 5. Comparison of variables
# 6. Arithmetic Operators
# 7. Variable Types
# 8. Common Errors
#
# **Last but not least**, an exercice, where you can take a glimpse of the programming fun 🥳. This exercice will follow the whole course, so be ready to upgrade it multiple times. You will need to send it to me **by 5pm Thursday next week.**
#
# ### <font color="teal">Evaluation</font>
# This lab will not be grade. I repeat, this lab will not count in your grade.
# However, following labs will take part in your evaluation.

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# * A program is a **set of instructions**
#     * Orders for the machine to execute later on
# * A program will be compilated for the machine to understand it
# * A compilated program is only binary code
#
# ## <font color="teal">Programming Languages</font>
# * Languages are divided by level :
#     1. High level: **Python**, Java, etc.
#     2. Low-Level: COBOL, FORTRAN, C, etc.
#     3. Assembly: some CPUs
#     4. Machine code
#     5. Micro-code: CPUs
#
# ## <font color="teal">What you need</font>
# * Logic:
#     * Propositional logic
#     * First-order logic
#     * Predicate logic
# * Rigor:
#     * Verify everything, every character, every content
#     * Order is important!
# * Patience:
#     * Verify/understand error logs
#     * Proceed step by step
#
# ## <font color="teal">What you will learn</font>
# 1. To **understand** and use basic types
# 2. To **implement** simple logic
# 3. To **write** simple code

# %% [markdown]
# ## <font color="teal">Python</font>
# Python is a high level programming language under free licence. It was created by Guido Van Rossum but since 2001 the development is lead by the [Python Software Foundation](http://www.python.org/psf/) (Guido was the *"benevolent dictator for life"* until july 2018).
#
# Language evolutions are detailed in Python Enhancement Proposals (PEP).
#
# ### <font color="teal">Python functions</font>
# To know what does each native Python functions, you need to access the documentation.
# * type : `help(print)`
# <small>`q` to exit the doc</small>
# * in your browser : [https://docs.python.org/3/library/functions.html](https://docs.python.org/3/library/functions.html)
# * or : [DevDocs](http://devdocs.io/)

# %% [markdown]
# Famous PEPs:
# * [PEP 20](https://www.python.org/dev/peps/pep-0020/) "Zen of Python"<sup>1</sup> ( `import this` in python console)
# * [PEP 8](https://www.python.org/dev/peps/pep-0008/) "Style Guide for Python Code"
#
# <sup>1</sup> "There should be one-- and preferably only one --obvious way to do it."

# %%
# show the code guidelines for Python
import this

# %% [markdown]
# # <font color="teal">**A Basic Instruction**</font>

# %% [markdown]
# We can print anything by using the `print()` function.
#
# ```python
# print( SOMETHING )
# ```
#
# As we have seen in the example programme during the lecture, there are two simple functions to print some text on the screen (i.e. in the console) and to get text from keyboard input from the user: `print` and `input` respectively.

# %%
# what does the print() function ?
help(print)

# %%
print('Hello world')

# %% [markdown]
# * Principle: 1 line = 1 instruction
# * Everything after `#` is a comment
# ```python
# # this is a comment !!!
# ```

# %%
print('hey') #first instruction
print('you') #second instruction (order is important)

# %%
print("hello!")
print("What is your name?")
name = input()
print("Nice to meet you ")
print(name)

# %% [markdown]
# You will have noticed that print inserts a newline everytime you use it. There are different ways in which you can print multiple things at once using print:
# *   Using string concatenation
# *   Using multiple parameters in print:
# ```python
# print(string1, string2, ...)
# ```
# *   Using string formating (multiple ways):
# ```python
# print(f"something {variable1} other thing {variable 2} last thing")
# ```
# or
# ```python
# print( "something %s other thing %s last thing" % (variable1, variable2)
# ```

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# Using the code cell below, **write the code to create a variable called `name` with your name as a string for value**, use the four ways of constructing a string for output above to write three times a message including \"Nice to meet you\", your name (from the variable) and an exlamation mark (!).

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# Did you think of adding comments? **Add one comment for each line of code**, briefly stating what it does.

# %% [markdown]
# # <font color="teal">**Variables**</font>

# %% [markdown]
# * Variables are data containers.
# * `=` is used to put value into a variable
# * Variable's content can be put into another variable
# ```python
# variable1 = variable2
# ```

# %%
# Variable initialization with None value assigned (i.e. empty)
my_variable = None
print(my_variable)

# %%
name = 'Gaël'
print(name)

# %%
# variables values
lastname = 'Guibon'
firstname = 'Gaël'
print(lastname)
print(firstname)
lastname = firstname
print(lastname, firstname) # multiple arguments can be passed into print function.
# They will automatically be separated by a space.

# %% [markdown]
# # <font color="teal">**Variables Names**</font>

# %% [markdown]
# Variables can have any names **EXCEPT the already declared keywords**.
# To show all the python keywords do:

# %%
import keyword # import libraries. this one is a standard library (i.e. already embedded with a standard Python installation)
print(keyword.kwlist)

# %% [markdown]
# * Variable names are alphanumeric values (upper or lowercase), or/and numbers, or/and underscores. Nothing more.
# * Variable names need to be clear and understandable. For instance:
# ```python
# birthdayDate = '01012005' # good
# date = '01012005' # bad
# xyhzi = '010120005' # very bad
# ```
# * It is recommended to follow the official Python advices [PEP 8](https://www.python.org/dev/peps/pep-0008/).

# %%
# Python does not accept this kind of variable name
my-super-username = 'Robert' # known as KebabCase (for real!)

# %%
1_does_not_work = 'bad name'

# %%
# Use this instead
mySuperUsername = 'Robert' # known as CamelCase 🐪
# or this
my_super_username = 'Robert' # known as SnakeCase 🐍
# print them to see that it works

# %% [markdown]
# # <font color="teal">**Variable Comparison**</font>

# %% [markdown]
# Here are some basic variable comparison operators:
# * `==` compares two variables' contents
# * `is` compares two variables' place in memory

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# In the code box below, **write some code to verify variable's identity**, i.e. to verify that the formated string (`f\"... {var1} ...\"`) and the concatenated string (`\"...\"+v1+\"...\"`) are indeed exactly the same.
#
# Hint: Your code should print `True` if they are.

# %%
# TODO: code me!!

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# Does this mean that they are stored in the same place in memory? **Write some code below to check whether or not they are**:

# %%
# TODO: code me!!

# %% [markdown]
# # <font color="teal">**Arithmetic Operators**</font>

# %% [markdown]
# `+` addition

# %%
2 + 5

# %% [markdown]
# `-` substraction

# %%
3 - 2

# %% [markdown]
# `*` multiplication

# %%
2 * 3

# %% [markdown]
# `/` division

# %%
36 / 6

# %% [markdown]
# `%` modulus (division remainder)

# %%
36 % 8

# %% [markdown]
# `//` Floor division (cut the result after the period)

# %%
3 // 2

# %% [markdown]
# `**` exponent

# %%
10 ** 2 * 4

# %% [markdown]
# * Operation order and priorities are the same as in mathematics
# * You can use parenthesis to define priorities

# %%
36 / (2*3)

# %% [markdown]
# * Of course, it works with variables

# %%
a = 3
b = 2
print(a*b)

# %% [markdown]
# ## <font color="teal">Playing with numbers</font>

# %% [markdown]
# The code box below contains a three-digit number, and 6 smaller numbers. You goal here is to play countdown (\"le compte est bon\" in French): Write an expression using operators such as `+`, `-`, `*`, `/`, `//`, `%`, etc. to try to get as close as possible to the three-digit number (result), using each of the smaller numbers (v1, v2, ...) at most one time.
#
# You can write your formula in one line (e.g. `myres = v1 + v2 * v4`) , or use intermediary variables:
# ```
# res1 = v2 \* v4
# res2 = v1 + res1
# ```
# If you write it in one line, remember that operators in Python follow the same precedence rule as operators in mathematics, i.e. `v1 + v2 * v4` is not the same as `(v1+v2) * v4`.
#
# so it is best to use parentheses when needed.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# **Print the result** you obtain and the absolute value of the difference between your result and the expected one, and **add a comment on the mumber of operations your solution requires**.

# %% [markdown]
# `abs()` is a built-in function that returns the absolute value of a number.

# %%
result = 539
v1 = 25
v2 = 50
v3 = 75
v4 = 10
v5 = 4
v6 = 4
# TODO: complete me!!

# %% [markdown]
# # <font color="teal">**Variable Types**</font>

# %% [markdown]
# * Data can have different forms, same goes for variables
# * Each variable has a **Type**
# * Here are the most commons types in Python:
#     * **String**: str() : string of characters (text)
#     * **Integer**: int() : integer numbers
#     * **Float**: float() : numbers with floating decimal points
#     * **Boolean**: bool() : True or False
#     * Long (*not in Python*)
#     * Char (*not in Python*)
#     * Struct (*not in Python*)
# * Python is a strong dynamic typed language
#     * dynamic = variable type is determined by the interpretor (compilor)
#     * strong = no implicit conversion of types

# %% [markdown]
# * Try this :

# %%
"Hello" + 1

# %% [markdown]
# It does not work as we try to concatenate a String (str) with an Integer (int).
#
# You can find the variable's type with `type()` function.

# %%
print( type('hello world') )
print( type(23) )
print( type(False) )
print( type(23.45) )

# %% [markdown]
# ## <font color="teal">Type Conversion</font>

# %% [markdown]
# * `str()`, `int()`, `float()` convert the passed argument as the desired type
# * `bool()` returns `True` if the argument is true, `False` otherwise.

# %%
int(3.14159265359) # transforms a float into an integer

# %%
"Hello" + str(1) # transforms an integer into a String and concatenate both Strings

# %% [markdown]
# # <font color="teal">**Errors Everywhere**</font>

# %% [markdown]
# <img src="data:image/png;base64,..."/>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# **Correct the code and add a comment.** The code below is full of (syntaxic and semantic, and even bugs) errors... making the minimal amount of changes, correct the code so that it runs without issue.
#
# Add a comment to each line where you changed something, indicating what you changed.

# %%
# TODO: fix me!!!!
import math # library with math stuff. Used for pi

# code to calculate the area, diameter and
# circunference of a circle
"""
To use it:
   - change the value of the radius variable
   - run the code
   - it should work #win!
"""
radius = 5   .2
.diameter    = 2*radius
circunference = 2 x math.pi*   radius
area = (mth.pi*radius)**2
print(f"Diameter: {diameter")
pint("Circunference: {circunference} (round down to "+int(circunference)+")")
print(f"Area: {aera}")
if area > 100:
  print("That's a big circle!)
   print("And I know what I'm talking about!") # removed a space in the indent

# %% [markdown]
# # <font color="teal">**Role Playing Game - Character Creation**</font>

# %% [markdown]
# ## <font color="teal">Objective</font>
# Construct a textual role playing game, but for this lab, you only have to create a on-demand character. Define some elements for the player to fill using the `input()` function. This character creation will come in handy for later labs 😉
#
# ## <font color="teal">Rules</font>
# * Player is given multiple attributes to fill
# * Player starts with 200 hp (health points)
# * Player have multiple items. (if in a heroic fantasy setting: potions, armor, weapons, etc. are some examples).

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# **Expand the following code cell** with values you want to ask the player. Then, when the character creation is finished, print all elements to the player.

# %%
# Get the input function and display a greeting message
print("Hello Player One, what's your character's name?")
char_name = input()
print(f"Welcome {char_name}!")
# TODO: complete me!
