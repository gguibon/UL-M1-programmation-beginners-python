# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 3</font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im)
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Reference Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.
#
# Please <font color="red">**upload your game (the textual Role Playing Game) as a .ipynb or .py file to the dedicated Arche assignment module by 5pm Thursday next week**</font>.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The main objectives are for you to master String operations and control flow (conditions, loops). This means at the end of this lab you should know :
# 1. (from Lab1): Instructions, Variables, Variable names conventions and comparisons, Arithmetic Operators, Variables types, common errors
# 2. More Strings operations
# 3. Conditions
# 4. Lists
# 5. Loops
#
# ### <font color="teal">Organization</font>
#
# First a set of reminders
# 1. Reminders of conditions, lists, loops, I/O (input/output) basic operations
#
# Followed by some exercices.
#
# **Last but not least**, you will have to finally start you own game! 🥳🎮 This means you will be able to create your game using only the elements you learned during the first two courses. You will need to upload it **by 5pm Thursday next week.**
#
# ### <font color="teal">Evaluation</font>
# <font color="red">**The game will be part of your grade.**</font> It will be evaluated on these elements (with the according weights summing up to 1 for the total grade). Note that late submissions will have a penalty.
#
# | instructions | syntax | design | variable | strings advanced | basic_operator | while_loop | conditions | for_loop | lists | dicts |
# |--------------|--------|--------|----------|------------------|----------------|------------|------------|----------|-------|-------|
# |          10% |     5% |     5% |      10% |              10% |            10% |        10% |        10% |      10% |   10% |   10% |
#
# - *instructions*: how you actually followed the assignment general instructions
# - *syntax*: how good is your code syntax
# - *design*: design of your code in regards to the algorithm you propose (i.e. the game)
# - *variable*: how much you master the variables (declaration, types, etc.)
# - *strings_advanced*: how much you master string concatenation, formatting, and so on
# - *basic_operator*: arithmetic operation mastery and other basic operators
# - *while_loop*: how much you master the use and advantages of the while loop
# - *for_loop*: the quality of usage and understanding in for loops
# - *lists*: how good is your list usage and handling
# - *dicts*: to which extent you understand dicts, how to use them, etc.

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# - **instructions** : `print()`
# - **basic operators** : logic (`and or`), math (`+ = - /`), membership (`in` `not in`)
# - **variables** : `name = city` `city = 'Nancy'`
# - **types concepts and basics** and conversion : `type()` `str()` `bool()` `int()` `float()` `list()`
# - list operations:
#   - `append(x)` : add an element at the end of the list
#   - `extend([x, y, z])` : add all these elements at the end of the list
#   - `pop([index])` : delete and return the last element of the list (or given indexes)
#   - `remove(x)` : remove first element with value x
#   - `index(x)` : return the index of the first element with value x
#   - `count(x)` : return the number of occurrences for x
#   - `sort()` : sort the list.
#   - `reverse()` : reverse the list order
#   - `insert(index, value)` : insert an element into a target index
# - **conditions** :
#   - ```python
#     if condition1:
#       print("if condition1 is true, print this")
#     elif condition2:
#       print("if condition 1 is not true but then condition2 is true")
#     else:
#       print("sinon")
#     ```
# - **loops** :
#   - ```python
#     for element in elements:
#       print(element)
#     ```
#   - ```python
#     for i in range(5):
#       print(i)
#     ```
#   - ```python
#       while bubbletea_exists and money>=5:
#         print("enjoy some bubble tea")
#     ```

# %% [markdown]
# # <font color="teal">**Dictionaries**</font>
# - Dictionaries are another Type of variable `dict()`
# - Follow only one concept: **Key and Value**
# - Can contain deeper informations, with explicit hierarchy
# - Data are not ordered (contrary to `list()` )
# - Value can be accessed by its associated Key
# - **Keys are unique** you cannot associate multiple values to one key.
# * `keys()` returns the list of keys, `values()` returns the list of values (you just need to change its type to list())

# %%
# initialize an empty dictionary
dico = {}
dico = dict() # both ways are corrects

# intialize with values
dico = { "key" : "value" }
print(dico)
# Out:
# {'key': 'value'}

# %%
player = { "name":"Thomas", "health":200 }
print(player)

ezgi = {'name':'Ezgi', 'age':19, 'friends':[] } # indeed, at the moment Ezgi does not have any friend 🥲
print(ezgi)
# Out:
# {'name': 'Thomas', 'health': 200}
# {'name': 'Ezgi', 'age': 19, 'friends': []}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 1**

# %% [markdown]
# **Create a dictionary representing your personal informations**:
# - your firstname
# - your lastname
# - your favorite food(s)
# - your future dream job
#
# Then print it

# %%
# CODE ME 🥹
gael = {
    'firstname': 'Gaël',
    'lastname': 'Guibon',
    'favorite_foods': ['litchi', "n'dolè", 'bubble tea'],
    'future_dream_job': "associate professor"
}
print("My data is as follows:", gael)
# Out:
# My data is as follows: {'firstname': 'Gaël', 'lastname': 'Guibon', 'favorite_foods': ['litchi', "n'dolè", 'bubble tea'], 'future_dream_job': 'associate professor'}

# %% [markdown]
# ## <font color="teal">Access data from a dict</font>
# - By specifying the key : number, boolean  or String
# - Commonly used with String keys

# %%
player["name"] = 'whatever'
print(player['name'])
print(player)
print( player['health'] )
# Out:
# whatever
# {'name': 'whatever', 'health': 200}
# 200

# %%
# get the list of keys
print( list( player.keys() ) )
print( player.keys())

# get the list of values
print( list( player.values() ) )
# Out:
# ['name', 'health']
# dict_keys(['name', 'health'])
# ['whatever', 200]

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 2**

# %% [markdown]
# **From your personal data, print only your favorite foods** one by one.

# %%
# CODE ME 🥹
for food in gael["favorite_foods"]:
  print(food)
# Out:
# litchi
# n'dolè
# bubble tea

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 3**

# %% [markdown]
# **Print all the keys from your personal data one by one**.

# %%
# CODE ME 🥹
for k in list(gael.keys()):
  print(k)

# another way
for k,v in gael.items():
  print(k)

# another way
for k in gael:
  print(k)
# Out:
# firstname
# lastname
# favorite_foods
# future_dream_job
# firstname
# lastname
# favorite_foods
# future_dream_job
# firstname
# lastname
# favorite_foods
# future_dream_job

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 4**

# %% [markdown]
# **Print all the values and their type from your personal data one by one**.

# %%
# CODE ME 🥹
for v in list(gael.values()):
  print(v)

# another way
for k,v in gael.items():
  print(v)
# Out:
# Gaël
# Guibon
# ['litchi', "n'dolè", 'bubble tea']
# associate professor
# Gaël
# Guibon
# ['litchi', "n'dolè", 'bubble tea']
# associate professor

# %% [markdown]
# ## <font color="teal">Insert or modify data in a dict</font>

# %%
# modify or create the key
player["items"] = ['bottle', 'laptop']
print(player)
# Out:
# {'name': 'whatever', 'health': 200, 'items': ['bottle', 'laptop']}

# %%
user = {'job': 'student'}
print('before',user)
user['job'] = 'teacher'
print('after',user)
# Out:
# before {'job': 'student'}
# after {'job': 'teacher'}

# %%
# delete a key : two methods
deletedValue = player.pop('items', None)
print(deletedValue)
print(player)

# if you are certain the key exists
player["items"] = ['bottle', 'laptop']
del player['items']
print(player)
# Out:
# ['bottle', 'laptop']
# {'name': 'whatever', 'health': 200}
# {'name': 'whatever', 'health': 200}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 5**

# %% [markdown]
# **Complete Ezgi's data with friends and some health points.** Then print Ezgi's data.

# %%
# CODE ME 🥹
ezgi['friends'].extend(['Matteo', 'Ikrame']) # now Ezgi have some friends ☺️
print(ezgi)
# Out:
# {'name': 'Ezgi', 'age': 19, 'friends': ['Matteo', 'Ikrame']}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 6**

# %% [markdown]
# **Make Ezgi older by 2 years.** Then print Ezgi's data.

# %%
# CODE ME 🥹
ezgi['age'] = ezgi['age'] + 2

# another way, same result
ezgi['age'] += 2
print(ezgi)
# Out:
# {'name': 'Ezgi', 'age': 23, 'friends': ['Matteo', 'Ikrame']}

# %% [markdown]
# ## <font color="teal">Explore a dict()</font>

# %%
# first populate the dict
# following steps are the same as:
# player = {'name':'élise',   'inventory': ['rose', 'pencil', 'smartphone'],   'grade':'noob'}
player = dict()
player['name'] = 'élise'
player['inventory'] = ['rose', 'pencil', 'smartphone']
player['grade'] = 'noob'
print('player =', player)
# get list of keys
print( player.keys(), type(list(player.keys())), len(player.keys()) )
# get list of values
print( player.values(), type(player.values()), len(player.values()) )
# Out:
# player = {'name': 'élise', 'inventory': ['rose', 'pencil', 'smartphone'], 'grade': 'noob'}
# dict_keys(['name', 'inventory', 'grade']) <class 'list'> 3
# dict_values(['élise', ['rose', 'pencil', 'smartphone'], 'noob']) <class 'dict_values'> 3

# %% [markdown]
# ### <font color="teal">Check if a key exists:</font>

# %%
nameFieldExists = 'name' in player
print( 'Does the "name" field exists in the dictionary "player" ?', nameFieldExists)
# Out:
# Does the "name" field exists in the dictionary "player" ? True

# %%
itemsFieldExists = 'items' in player
print( 'Does the "items" field exists in the dictionary "player" ?', itemsFieldExists)
# Out:
# Does the "items" field exists in the dictionary "player" ? False

# %% [markdown]
# ### <font color="teal">Iterate over fields in a dict</font>

# %%
for key, value in player.items():
    print('key =', key, ' ; value =', value)
# Out:
# key = name  ; value = élise
# key = inventory  ; value = ['rose', 'pencil', 'smartphone']
# key = grade  ; value = noob

# %% [markdown]
# ### <font color="teal">Get or add field and value</font>
# `setdefault(key, defaultValue)` insert the value associated to the key. If the key does not exist, it adds the key associated to `defaultValue`.

# %%
player.setdefault('age', 0)
print(player)
# Out:
# {'name': 'élise', 'inventory': ['rose', 'pencil', 'smartphone'], 'grade': 'noob', 'age': 0}

# %% [markdown]
# ### <font color="teal">Safely access non present field</font>
# Using `player[key]` will yield an error.
# You can safely try to access a field by using `player.get(key)`.
# Returns the value if the key exists, else returns None.
#
# ``
# (in pseudo algo)
# IF key exists:
#     RETURN the associated value
# ELSE:
#     RETURN None
# ``

# %%
print( player['unknownKey'] ) # gives an error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-078263549da7> in <cell line: 1>()
# ----> 1 print( player['unknownKey'] ) # gives an error
#
# KeyError: 'unknownKey'

# %%
print(player)
print( player.get('unknownKey')) # returns None
print( player.get('name') ) # it exists
# Out:
# {'name': 'élise', 'inventory': ['rose', 'pencil', 'smartphone'], 'grade': 'noob', 'age': 0}
# None
# élise

# %% [markdown]
# ## <font color="teal">Represent bigger data</font>

# %% [markdown]
# <img height="400" src="data:image/png;base64,..."/>

# %% [markdown]
# Dictionary can be put as value into another dictionary
# - With variable types, especially dict() and list() you can handle more interesting data.
# - You will often need to represent **nested data**

# %%
# example
user = {
    'name': 'Tiankai', # str()
    'age': 19, # int()
    'money': 24000.56, # float(), decimal being the cents
    'job': 'student', # str()
    'friends': ['Alicia', 'Bineta'], # list() of two str()
    'stats': {
        'social': 'very friendly', # str()
        'seriousness': 'perfect', # str()
        'formerEmployeee': False # bool()
    } # dict()
} # dict()

print(user)
print(user['stats']['social'])
# Out:
# {'name': 'Tiankai', 'age': 19, 'money': 24000.56, 'job': 'student', 'friends': ['Alicia', 'Bineta'], 'stats': {'social': 'very friendly', 'seriousness': 'perfect', 'formerEmployeee': False}}
# very friendly

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 7**

# %% [markdown]
# **Add your skills as a "skills" key in your personal data. For each skill, insert a grade from 0 to 10.** from before. Then print your personal data.

# %%
# CODE ME 🥹
gael["skills"] = {"litchi_eater": 10, "social": 5, "patience": 7}
print(gael)
# Out:
# {'firstname': 'Gaël', 'lastname': 'Guibon', 'favorite_foods': ['litchi', "n'dolè", 'bubble tea'], 'future_dream_job': 'associate professor', 'skills': {'litchi_eater': 10, 'social': 5, 'patience': 7}}

# %% [markdown]
# # <font color="teal">**Basic Role Playing Game 2.0**</font>

# %% [markdown]
# * Objective: **make a textual role playing game using all notions**. The game is only text with choices, conditions to verify the choices and player status.
#
# ## <font color="teal">Rules</font>
# * Player advance from a room to another by textually selecting one of the rooms.
# * Player starts with 200 hp (health points)
# * A bad decision cost the player to lose 25 hp.
# * For each actions, display it from a list of Strings
# * **Represent data as dictionaries or a big nested dict()** (see example below)

# %%
 # Get the input function and display a greeting message
player = dict()
print("Hello Player One, what's your name?")
player['name'] = input()
print("Welcome", player['name'])

choice = ''
events = {
    '1': {
        'message': 'Game Over! Try again' + player['name']
    },
    '2': {
        'messages': ['Upon opening the door, you can see a huge fest with exquisite meals everywhere.', 'heyy'],
        'follow':{}
    }
}
pastEvents = []

while choice not in events.keys():
    print('''Your are in a tiny room. Humidity fills the air but your stomach reminds you that you are very hungry.
    You are in front of two doors. Behind the first one you can hear muffled voices.
    Behind the second one you can smell something intriguing.''')
    print('Which door do you choose? Type', list(events.keys())[0], 'for the first room and', list(events.keys())[1],
          'for the second room.')
    choice = input()
    if choice in events.keys():
        pastEvents.append(choice)
#         if type(events[choice]['message']) == str():
        if 'messages' in events[choice]:
            for message in events[choice]['messages']:
                print(message)
        else:
            print(events[choice]['message'])
    else:
        print('WRONG : Possible choices', list(events.keys()) )

print(pastEvents)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 8**

# %% [markdown]
# * **Complete the Role Playing Game skeleton or your game** by adding choices, player HP, etc.
# * *Tip: this kind of game is a decision tree of choices.* : the decision tree is represented as a nested dictionary
# * Use while to keep the playing going on until certain conditions
# * Use for to display player' items or actions
