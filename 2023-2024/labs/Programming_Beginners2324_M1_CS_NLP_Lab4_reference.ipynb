# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 4</font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im)
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Reference Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.
#
# Please <font color="red">**upload your game (the textual Role Playing Game) as a .py file in the Arche platform by 5pm Thursday next week**</font>.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The objective is for you to **understand functions, their usage, decomposition and a bit more about abstraction**. This means at the end of this lab you should know :
# 1. (from Lab1): Instructions, Variables, Variable names conventions and comparisons, Arithmetic Operators, Variables types, common errors
# 2. (from Lab2): lists, loops, conditions, String operations
# 3. (from lab3): More List Operations
# 4. (from lab3): Dictionaries
# 6. Functions
# 7. Built-in function usage and import
#
# ### <font color="teal">Organization</font>
#
# First a set of reminders
#
# Followed by some exercices and examples on functions.
#
# **Last but not least**, you will have to code a new game or adapt the previous one with functions! 🥳🎮 You will need to send it to me **by 5pm Thursday next week.**
#
# ### <font color="teal">Evaluation</font>
# <font color="red">**The game will be part of your grade.**</font> It will be evaluated on these elements (with the according weights summing up to 1 for the total grade). Note that late submissions will have a penalty.
#
# | instructions | syntax | design | variable | strings_advanced | basic_operator | while_loop | conditions | for_loop | lists | dicts | functions |
# |--------------|--------|--------|----------|------------------|----------------|------------|------------|----------|-------|-------|-----------|
# |          10% |     5% |     5% |       5% |              10% |             5% |        10% |        10% |      10% |   10% |   10% |       10% |
#
# - *instructions*: how you actually followed the assignment general instructions
# - *syntax*: how good is your code syntax
# - *design*: design of your code in regards to the algorithm you propose (i.e. the game)
# - *variable*: how much you master the variables (declaration, types, etc.)
# - *strings_advanced*: how much you master string concatenation, formatting, and so on
# - *basic_operator*: arithmetic operation mastery and other basic operators
# - *while_loop*: how much you master the use and advantages of the while loop
# - *for_loop*: the quality of usage and understanding in for loops
# - *lists*: how good is your list usage and handling
# - *dicts*: to which extent you understand dicts, how to use them, etc.
# - *functions*: the quality of your functions, docstrings, arguments, recursivity, etc.

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# - **instructions** : `print()`
# - **basic operators** : logic (`and or`), math (`+ = - /`), membership (`in` `not in`)
# - **variables** : `name = city` `city = 'Nancy'`
# - **types concepts and basics** and conversion : `type()` `str()` `bool()` `int()` `float()` `list()`
# - list operations:
#   - `append(x)` : add an element at the end of the list
#   - `extend([x, y, z])` : add all these elements at the end of the list
#   - `pop([index])` : delete and return the last element of the list (or given indexes)
#   - `remove(x)` : remove first element with value x
#   - `index(x)` : return the index of the first element with value x
#   - `count(x)` : return the number of occurrences for x
#   - `sort()` : sort the list.
#   - `reverse()` : reverse the list order
#   - `insert(index, value)` : insert an element into a target index
# - **conditions** :
#   - ```python
#     if condition1:
#       print("if condition1 is true, print this")
#     elif condition2:
#       print("if condition 1 is not true but then condition2 is true")
#     else:
#       print("sinon")
#     ```
# - **loops** :
#   - ```python
#     for element in elements:
#       print(element)
#     ```
#   - ```python
#     for i in range(5):
#       print(i)
#     ```
#   - ```python
#       while bubbletea_exists and money>=5:
#         print("enjoy some bubble tea")
#     ```
# - **dictionaries** :
#   - ```python
#     data = {"name":"gael"}
#     print(data['name'])
#     ```

# %% [markdown]
# # <font color="teal">**Built-in Modules**</font>

# %% [markdown]
# Python possesses some built-in modules. These modules possess function.
#
# To import a module (and thus be able to it afterwards):

# %%
import random

# %% [markdown]
# Now you've just imported the `random` built-in module which gives you multiple functions to after generate or select random elements.

# %% [markdown]
# `random.randomint(2,200)` returns a random integer between 2 and 200 (2 and 200 are included)

# %%
# generate a random number between 0 and 10
random_integer = random.randint(0, 10)
print(f"a random number between 0 and 10: {random_integer}")
# Out:
# a random number between 0 and 10: 6

# %% [markdown]
# `random.choice(mylist)` returns a random element from a `mylist`

# %%
# returns a random element from a sequence (list for instance)
big_cats = ["cat🐈", "kitty🐱", "lion🦁", "tiger🐅", "leopard🐆"]
random_big_cat = random.choice(big_cats)
print(f"The {random_big_cat} is part of the 🐾 big cats 🐾 family. Not at all a doggy 🐶")
# Out:
# The leopard🐆 is part of the 🐾 big cats 🐾 family. Not at all a doggy 🐶

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 1**

# %% [markdown]
# <img height="200px" src="data:image/png;base64,..."/>

# %% [markdown]
# **Print a random fashion brand name.**

# %%
# CODE ME PRETTY PLEAAAASE 🥺

# returns a random element from a sequence (list for instance)
brands = {"fashion": ["Gucci", "Dior", "Chanel", "Louis Vuitton", "Hermès", "Prada"], "jewelry": ["Tiffany", "Cartier"]}

# let's print a random fashion brand
print( random.choice(brands["fashion"]) )
# Out:
# Hermès

# %%
brands
# Out:
# {'fashion': ['Gucci', 'Dior', 'Chanel', 'Louis Vuitton', 'Hermès', 'Prada'],
#  'jewelry': ['Tiffany', 'Cartier']}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 2**

# %% [markdown]
# **Complete the `brands`** variable with several other jewelry brands.
# Then **randomly select both the fashion brand and the jewelry** you will wear today!

# %%
# CODE ME PRETTY PLEASE 🥺

brands['jewelry'].extend(["Swarovski", "Saint Laurent", "Shashi"])
print(f"I will wear a {random.choice(brands['fashion'])} t-shirt sublimed by {random.choice(brands['jewelry'])} earrings 😎" )
# Out:
# I will wear a Prada t-shirt sublimed by Tiffany earrings 😎

# %% [markdown]
# # <font color="teal">**Functions**</font>

# %% [markdown]
# A function is a **subprogram**, a way to reuse the same code again and again by just calling it.
#
#
#
# Functions have:
# - A name
# - Arguments (if specified)
#
# Functions do:
# - A process
# - Return something (if specified)
#
#
# Functions allow proper abstraction of some ideas. Think about a recipe:
# 1. boil water
# 2. put the tapioca in it
# 3. make some green tea
# 4. add milk
# 5. put everything into a cup
# 6. enjoy your bubble tea 🧋
#
# All of these steps are functions.
# The `boilwater()` function is a set of instructions (go to the tap, fill the pan, etc.). It returns the boiled water.

# %% [markdown]
# ## <font color="teal">Use *docstrings* to documentate functions:</font>
# ```python
# """ this function does this process and return that value but need those arguments """
# ```

# %%
def sayHelloToSomebody(arg1):
    """
    This superb function needs 1 argument which is the name fo the person I want to say hello to.
    It returns None (so this function return no value, it only prints something)
    """
    print(arg1)
    return None

print( sayHelloToSomebody('Anna') )
# Out:
# Anna
# None

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 3**

# %% [markdown]
# **Add a docstrings** to the function below

# %%
# I NEED A DOCSTRING PLZZZZ 🥺🥺🥺

def get_flag(countryname, flagmapping={"france": "🇫🇷", "spain": "🇪🇸", "dominican republic": "🇩🇴", "singapore": "🇸🇬"}):
  """
  Returns the flag associated to the given country name.
  Args:
    countryname (str): the name of your country in lowercase
    (optional) flagmapping (dict): dictionary with country names as keys and emoji flag as value. The default value is {"france": "🇫🇷", "spain": "🇪🇸", "dominican republic": "🇩🇴", "singapore": "🇸🇬"}

  Returns:
    (str) emoji flag in an utf-8 encoding
  """
  if countryname not in flagmapping:
    return "Dear customer, we don't know this country, you may want to give you custom flagmapping dictionary in the dedicated optional argument named 'flagmapping' "
  else:
    return flagmapping[countryname]

# %% [markdown]
# ## <font color="teal">Examples</font>
# This function returns the sum of the three arguments.

# %%
def sumItUp(arg1, arg2, arg3):
    """
    Well, this is but a sum of the 3 args.
    """
    return arg1 + arg2 + arg3

# %%
# Now that I defined my function I can use it like this
resultSum = sumItUp(2,3,-5)
print(resultSum)
# Out:
# 0

# %% [markdown]
# This function return the mean of a list of numbers arguments.

# %%
def avg(listOfNumbers):
    ''' This computes the mean of a given list of numerical values  '''
    return sum(listOfNumbers) / len(listOfNumbers)

dogAges = [4,7]
print( avg(dogAges) )
# Out:
# 5.5

# %%
# a more concrete example : a function dedicated to get the average age of students
students = [{"name":"Ahana", "age":26},{"name":"Ilan", "age":18},{"name":"Julie", "age":22}]
# let's create an empty list to store the ages of the students
ages = []
# now we iterate over the list of dictionaries
for student in students:
  # for each student we add its age to the ages list
  ages.append(student["age"])

# now our list of ages is filled, let's look at its content
print("now my list of ages is", ages)

# given our function avg() accepts a list of numbers, we can now give the list of ages to it. we store the result returned by the function into a variable
resultAvg = avg(ages)
# now we can print the average
print(f"On average, students are {resultSum} years old!")
# Out:
# now my list of ages is [26, 18, 22]
# On average, students are 0 years old!

# %% [markdown]
# ## <font color="teal">Optional arguments with default value</font>
# - Some arguments can have a default value, hence their declaration is optional.
# - Mandatory args always comes before optional ones

# %%
# DEFine the function
def createStudent( age, grade, name='noname'):
    """ This creates a student dict with default name as 'noname' """
    return {'name':name, 'age':age, 'grade':grade}

## now use it, try to uncomment the following lines
# print( createStudent(19, 20) )
print( createStudent( 19, 20, name='Praise-Esther' ) )
# as you can see, the name arg is optional
# Out:
# {'name': 'Hanna', 'age': 19, 'grade': 20}

# %% [markdown]
# ⚠️ this will not work due to the optional arg placed before a mandatory one

# %%
# this will not work due to the optional arg placed before a mandatory one
createStudent(name='thisStudent', 19, 20)
# Out:
#   File "<ipython-input-13-95c5493f89c8>", line 2
#     createStudent(name='thisStudent', 19, 20)
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ⚠️ this will not work due to the lack of mandatory args (here `age`and `grade`)

# %%
# this will not work due to the lack of mandatory args
createStudent(19)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-17c217ca846a> in <cell line: 2>()
#       1 # this will not work due to the lack of mandatory args
# ----> 2 createStudent(19)
#
# TypeError: createStudent() missing 1 required positional argument: 'grade'

# %%
# DEFine the function
def createStudent( age, grade, name='noname'):
    """ This creates a student dict with default name as 'noname' """
    return {'name':name, 'age':age, 'grade':grade}
roxane = createStudent(19, )
print(roxane)
# now use it
print( createStudent(19, 20) )
print( createStudent( 19, 20, name='superStudent' ) )
# as you can see, the name arg is optional
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-96eb741c1db0> in <cell line: 5>()
#       3     """ This creates a student dict with default name as 'noname' """
#       4     return {'name':name, 'age':age, 'grade':grade}
# ----> 5 roxane = createStudent(19, )
#       6 print(roxane)
#       7 # now use it
#
# TypeError: createStudent() missing 1 required positional argument: 'grade'

# %% [markdown]
# ## <font color="teal">Arbitrary number of arguments</font>

# %%
import random

def showGroup(groupName, *students, **infos):
    print('group = ', groupName)
    print('='*5, 'Students', '='*5)
    for student in students:
        print(student)
    print('='*5, 'Info', '='*5)
    for status, number in infos.items():
        print(status, number)

pythoners = ["Mathilde", "Jonas", "Kira", "Adam", "Efua", "Enzo", "Elena"]
showGroup('the best group', random.choice(pythoners), random.choice(pythoners), pythonLovers=2, pythoners=len(pythoners))
# Out:
# group =  the best group
# ===== Students =====
# Mathilde
# Kira
# ===== Info =====
# pythonLovers 2
# pythoners 7

# %% [markdown]
# ## <font color="teal">Variable scope</font>
# - Variables defined inside a function possess a local scope (not accessible outside of this function)
# - Variables defined outside a function possess a global scope
#
# Beware of the indentation!
#
# For instance:

# %%
globalVar = 'I am defined outside a function'
def doThis(myVar):
    scopedVar = 'I am defined inside a function'
    globalVar = 'yes' # available because it is global
    print(scopedVar)
    return True
print(scopedVar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6ec61cd71ae0> in <cell line: 7>()
#       5     print(scopedVar)
#       6     return True
# ----> 7 print(scopedVar)
#       8
#
# NameError: name 'scopedVar' is not defined

# %%
print(globalVar)
# Out:
# I am defined outside a function

# %% [markdown]
# ⚠️ this one below does not work because we are not inside the function where it is defined

# %%
print(scopedVar)
# it does not work because we are not inside the function where it is defined
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e8fec9eacbc6> in <cell line: 1>()
# ----> 1 print(scopedVar)
#       2 # it does not work because we are not inside the function where it is defined
#
# NameError: name 'scopedVar' is not defined

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 4**

# %% [markdown]
# **Using only one function, randomly print one element from the inventory. Then, directly print the favorite element if it is present and specified.**

# %%
import random

inventory = {"strawberry": "🍓", "mango": "🥭", "baguette": "🥖", "bubble tea": "🧋", "curry": "🍛"}

# CODE ME PRETTY PLEASE 🥺
def retrieveItem(inventory, favorite=None):
  """ given a inventory (dict), returns a random element or the favorite item if present in the inventory """
  if (favorite == None) or (favorite not in inventory):
    random_key = random.choice(list(inventory.keys()))
    return inventory[random_key]
  return inventory[favorite]

random_item = retrieveItem(inventory)
bubble_tea = retrieveItem(inventory, favorite="bubble tea")

print(f"Here is a random item from your inventory {random_item}")
print(f"Here is your favorite item you possess {bubble_tea}")
# Out:
# Here is a random item from your inventory 🧋
# Here is your favorite item you possess 🧋

# %% [markdown]
# ## <font color="teal">**Random Wardrobe Selection**</font>

# %% [markdown]
# <img height="200px" src="data:image/png;base64,..." />

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 5**

# %% [markdown]
# **Create a function which asks the user its favorite clothes then randomly selects parts of the clothes you will wear.** Then it prints it.
#
# 💡 You can either do it as one main function or multiple ones with a main function.

# %%
# CODE ME PRETTY PLEASE 🥺
import random

wardrobe = {
    "top": ["t-shirt", "sweater", "hoodie", "long sleeve top"],
    "bottom": ["jean", "skirt", "short", "trouser"],
    "shoes": ["boots","heeled shoes", "flat shoes", 'flip flop'],
    "accessories": ["earrings", "necklace", "ring", "hat"]
}

# code the function
def ask_like(category, elements):
  choices = ["y", "n"]
  choice = ""
  filtered_elements = []
  print(f"Let's see what {category} you like.")
  for element in elements:
    choice = ""
    while choice not in choices:
      choice = input(f"Do you like {element}? ('y' for yes or 'n' for no)")
      if choice == "y":
        filtered_elements.append(element)
        print(element,"✔️")
      elif choice == 'n':
        print(element, "❌")
  return filtered_elements

def dressup():
  # intialize a dict for the final selected clothes
  clothes_selected = {"top":"", "bottom": "", "shoes":"", "accessories": ""}
  # for all elements and categories
  for category, pieces in wardrobe.items():
    # ask the clothes the user likes
    wardrobe[category] = ask_like(category, pieces)
  for category, pieces in  wardrobe.items():
    # now randomly select the clothes
    clothes_selected[category] = random.choice(pieces)
    print('='*10, category, '='*10)
    print(f"{clothes_selected[category]}")

dressup()
# Out:
# Let's see what top you like.
# Do you like t-shirt? ('y' for yes or 'n' for no)y
# t-shirt ✔️
# Do you like sweater? ('y' for yes or 'n' for no)y
# sweater ✔️
# Do you like hoodie? ('y' for yes or 'n' for no)y
# hoodie ✔️
# Do you like long sleeve top? ('y' for yes or 'n' for no)y
# long sleeve top ✔️
# Let's see what bottom you like.
# Do you like jean? ('y' for yes or 'n' for no)y
# jean ✔️
# Do you like skirt? ('y' for yes or 'n' for no)n
# skirt ❌
# Do you like short? ('y' for yes or 'n' for no)n
# short ❌
# Do you like trouser? ('y' for yes or 'n' for no)y
# trouser ✔️
# Let's see what shoes you like.
# Do you like boots? ('y' for yes or 'n' for no)y
# boots ✔️
# Do you like heeled shoes? ('y' for yes or 'n' for no)n
# heeled shoes ❌
# Do you like flat shoes? ('y' for yes or 'n' for no)y
# flat shoes ✔️
# Do you like flip flop? ('y' for yes or 'n' for no)n
# flip flop ❌
# Let's see what accessories you like.
# Do you like earrings? ('y' for yes or 'n' for no)n
# earrings ❌
# ...

# %% [markdown]
# # <font color="teal">**Basic Role Playing Game**</font>

# %% [markdown]
# * Objective: construct a textual role playing game. The game is only text with choices, conditions to verify the choices and player status.
#
# ## <font color="teal">Rules</font>
# * Player advance from a room to another by textually selecting one of the rooms.
# * Player starts with 200 hp (health points)
# * A bad decision costs the player to lose 25 hp.
# * For each actions, display it from a list of Strings
# * **Represent data as dictionaries or a big nested dict()** (see example below)
# * **Use functions** to remove code duplicates and reduce the line numbers
# * **Add status and health modification function**

# %%
# Example with dict and basic functions and health management
player = dict()
print("Hello Player One, what's your name?")
player['name'] = input()
player['health'] = 200
print("Welcome", player['name'])

events = {
    '1': {
        'message': 'Game Over! Try again ' + player['name']
    },
    '1': {
        'message': '''Upon opening the door, you can see a huge fest with exquisite meals everywhere.
                   Will you eat it?''',
        'paths': {
            'y': { 'message': 'You ate poison and lost 20 hp', 'hploss': 20},
            'n': { 'message': 'You are still hungry and lose a bit of hp from hunger', 'hploss': 10}
        }
    }
}
pastChoices = []

def removeHealth(amount):
    '''  remove some health from the player. And check if he died. '''
    player['health'] -= amount
    if player['health'] <= 0:
        return False
    else:
        return True

def askAction(event, choices):
    '''
    Ask an action from the user. Stay alive while the action is not recognized.
    '''
    choice = ''
    while choice not in choices:
        print('player status', player)
        choice = input()
        if choice in choices:
            print(event[choice]['message'])
            if 'hploss' in event[choice]:
                alive = removeHealth(event[choice]['hploss'])
                if not alive : break
            pastChoices.append(choice)
            if 'paths' in event[choice]:
                askAction(event[choice]['paths'], list(event[choice]['paths'].keys()) )
        else:
            print('WRONG : Possible choices', choices )
    return True

print('''Your are in a tiny room. Humidity fills the air but your stomach reminds you that you are very hungry.
        You are in front of two doors. Behind the first one you can hear muffled voices.
        Behind the second one you can smell something intriguing.''')
print('Which door do you choose? Type', list(events.keys())[0], 'for the first room and', list(events.keys())[1],
              'for the second room.')

askAction(events, list(events.keys()) )

print('You finished playing the game. Here are your past actions :', pastChoices)
print('Here are your remaining stats', player)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 6**

# %% [markdown]
# **Code your game from scratch using functions**
#
# 💡 Tips
# - Use functions when you need to copy paste / repeat some code
# - You need to use all the notions you learned:
#   - variables
#   - list
#   - for loop
#   - while loop
#   - dictionaries
#   - built-in functions
#   - functions you defined
