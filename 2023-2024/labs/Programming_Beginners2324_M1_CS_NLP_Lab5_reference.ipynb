# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 5</font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im)
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Reference Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.
#
# Please <font color="red">**upload your game (the textual Role Playing Game) as a .py file in the Arche platform by 5pm Thursday next week**</font>.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The objective is for you to **get a hold on external data (files, json), understand tuples, and dive into recursive functions**. This means at the end of this lab you should know :
# 1. (from Lab1): Instructions, Variables, Variable names conventions and comparisons, Arithmetic Operators, Variables types, common errors
# 2. (from Lab2): lists, loops, conditions, String operations
# 3. (from lab3): More List Operations
# 4. (from lab3): Dictionaries
# 6. (from lab4): Functions
# 7. (from lab4): Built-in function usage and import
# 8. Files, jsons, tuples
# 9. Recursive functions
#
# ### <font color="teal">Organization</font>
#
# First a set of reminders
#
# Followed by some exercices and examples on functions.
#
# **Last but not least**, you will have to code a new game or adapt the previous one with functions! 🥳🎮 You will need to send it to me **by 5pm Thursday next week.**
#
# ### <font color="teal">Evaluation</font>
# <font color="red">**The game will be part of your grade.**</font> It will be evaluated on these elements (with the according weights summing up to 1 for the total grade). Note that late submissions will have a penalty.
#
# | instructions | syntax | design | variable | strings_advanced | basic_operator | while_loop | conditions | for_loop | lists | dicts | functions | files |
# |--------------|--------|--------|----------|------------------|----------------|------------|------------|----------|-------|-------|-----------|-------|
# |          10% |     5% |     5% |       5% |               5% |             5% |         5% |         5% |       5% |   10% |   10% |       10% |   20% |
#
# - *instructions*: how you actually followed the assignment general instructions
# - *syntax*: how good is your code syntax
# - *design*: design of your code in regards to the algorithm you propose (i.e. the game)
# - *variable*: how much you master the variables (declaration, types, etc.)
# - *strings_advanced*: how much you master string concatenation, formatting, and so on
# - *basic_operator*: arithmetic operation mastery and other basic operators
# - *while_loop*: how much you master the use and advantages of the while loop
# - *for_loop*: the quality of usage and understanding in for loops
# - *lists*: how good is your list usage and handling
# - *dicts*: to which extent you understand dicts, how to use them, etc.
# - *functions*: the quality of your functions, docstrings, arguments, recursivity, etc.
# - *files*: your usage of files and how you leverage it

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# - **instructions** : `print()`
# - **basic operators** : logic (`and or`), math (`+ = - /`), membership (`in` `not in`)
# - **variables** : `name = city` `city = 'Nancy'`
# - **types concepts and basics** and conversion : `type()` `str()` `bool()` `int()` `float()` `list()`
# - list operations:
#   - `append(x)` : add an element at the end of the list
#   - `extend([x, y, z])` : add all these elements at the end of the list
#   - `pop([index])` : delete and return the last element of the list (or given indexes)
#   - `remove(x)` : remove first element with value x
#   - `index(x)` : return the index of the first element with value x
#   - `count(x)` : return the number of occurrences for x
#   - `sort()` : sort the list.
#   - `reverse()` : reverse the list order
#   - `insert(index, value)` : insert an element into a target index
# - **conditions** :
#   - ```python
#     if condition1:
#       print("if condition1 is true, print this")
#     elif condition2:
#       print("if condition 1 is not true but then condition2 is true")
#     else:
#       print("sinon")
#     ```
# - **loops** :
#   - ```python
#     for element in elements:
#       print(element)
#     ```
#   - ```python
#     for i in range(5):
#       print(i)
#     ```
#   - ```python
#       while bubbletea_exists and money>=5:
#         print("enjoy some bubble tea")
#     ```
# - **dictionaries** :
#   - ```python
#     data = {"name":"gael"}
#     print(data['name'])
#     ```

# %% [markdown]
# # <font color="teal">**Tuples**</font>

# %% [markdown]
# Tuples are another type of sequence. You can consider them as a list with less functionalities: they are **ordered** and **unchangeable (also called immutable)**. This means tuples do NOT possess functions such as update(), remove() and so on.
#
# Tuples are defined using parentheses `my_tuple = ()`.

# %%
# creates an empty tuple named a
a = ()

# %% [markdown]
#  Tuples can have multiple types in it (same as a list).

# %%
my_tuple = ("i am a string", 10, {"key":"value"}, ())

# %% [markdown]
# You can always change a list to a tuple (also called type casting).

# %%
names = ["Bineta", "Ezgi", "Amélie"]
names = tuple(names)
print(type(names))
# Out:
# <class 'tuple'>

# %% [markdown]
# Now you can see that the type of the names is a tuple. You can change a tuple to a list and vice-versa as you see fit. Convenient isn't it? 😛

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 1**

# %% [markdown]
# From the `names` variable, print "Amélie" by using the tuple index (same as a list).

# %%
# CODE ME PLZ 🥺
print(names[2])
# Out:
# Amélie

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 2**

# %% [markdown]
# **Create a tuple with your favorite book titles.** Then print it.

# %%
# CODE ME PLZ 🥺
book_titles = ("Le comte de Monte-Cristo", "Le procès", "Mémoire de deux jeunes mariées")
print(book_titles)
# Out:
# ('Le comte de Monte-Cristo', 'Le procès', 'Mémoire de deux jeunes mariées')

# %% [markdown]
# Tuples are really useful to represent data that will not change. Let's take an example.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 3**

# %% [markdown]
# **Create a list of multiple tuples.** Each tuple contains two values: the book title and the author.
# **Then print each tuple one at a time**

# %%
# CODE ME PLZ 🥺
books = [("Le comte de Monte-Cristo", "Alexandre Dumas"), ("Le procès", "Franz Kafka"), ("Mémoire de deux jeunes mariées", "Honoré de Balzac")]
for book in books:
  print(book)
# Out:
# ('Le comte de Monte-Cristo', 'Alexandre Dumas')
# ('Le procès', 'Franz Kafka')
# ('Mémoire de deux jeunes mariées', 'Honoré de Balzac')

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 4**

# %% [markdown]
# **Create a function that takes one tuple and prints nicely** the title and author of a book.
#
# Then use it to display each tuple from the previous list of tuples (representing books)

# %%
# CODE ME PLZ 🥺
def printBook(book_tuple):
  """prints a book represented as a tuple with two values: title and author as String values"""
  msg = f'"{book_tuple[0]}" is a masterpiece from {book_tuple[1]}'
  print(msg)

books = [("Le comte de Monte-Cristo", "Alexandre Dumas"), ("Le procès", "Franz Kafka"), ("Mémoire de deux jeunes mariées", "Honoré de Balzac")]
for book in books:
  printBook(book)
# Out:
# "Le comte de Monte-Cristo" is a masterpiece from Alexandre Dumas
# "Le procès" is a masterpiece from Franz Kafka
# "Mémoire de deux jeunes mariées" is a masterpiece from Honoré de Balzac

# %% [markdown]
# By default, if you put multiple element to return from a function, it will be mapped as a tuple.

# %%
def myFunction(num1, num2):
  """get the sum of two numbers and returns them along with their sum (as a tuple obviously~)"""
  return num1, num2, num1+num2

# %%
print(myFunction(2, 3))
# Out:
# (2, 3, 5)

# %%
print("this function returns a", type(myFunction(2, 3)))
# Out:
# this function returns a <class 'tuple'>

# %% [markdown]
# # <font color="teal">**Files**</font>

# %% [markdown]
# A program often need to access a file from your file system. For this you need:
# 1. A **file path** (*i.e.* the location). It can be:
#     - absolute: `/home/gael/Documents/my_super_file.txt`
#     - relative: `Documents/my_super_file.txt` (when you want to access it from `/home/gael/`
# 2. A **function** `open()` to handle files:
#     - **Create** a file from scratch: `myFile = open(file_path, 'w')`
#     - **Write** in a file opened with 'w': `myFile.write('hello world')`
#     - **Read** a file: `myFile = open(file_path, 'r')`
#     - **Close** a file: `myFile.close()`

# %% [markdown]
# Create a file named 'test.txt':

# %%
myFile = open('test.txt', 'w') # create the file with 'w' access (w = write) and get the file object variable

# %% [markdown]
# Write a String content into the file:

# %%
myFile.write('All hail Python') # write function is available if the file was opened with 'w'

# %% [markdown]
# Always close a file once you are done with it:

# %%
myFile.close()

# %% [markdown]
# Read a file and get the value into a variable:

# %%
myFile = open('test.txt', 'r') # open an existing file with 'r' (r = read)
fileContent = myFile.read() # put the content into a variable
myFile.close()
print(fileContent) # display the content

# %% [markdown]
# Append content to a file:

# %%
myFile = open('test.txt', 'a') # a = append w = write r = read
myFile.write('\nAnd Java !')
myFile.close()

# %% [markdown]
# Read the file again to display its new content

# %%
myFile = open('test.txt', 'r')
newContent = myFile.read()
myFile.close()
print(newContent)

# %% [markdown]
# Shortcut to autoclosing files (the `with` context - the context is defined by the indentation):

# %%
# with open('students.txt', 'w') as f:
#     f.write('Students:\n')

# students = ['Ilan', 'Adam', 'Matteo']
# with open('students.txt', 'a') as f:
#     for student in students:
#         f.write(student + '\n')

with open('students.txt', 'r') as f:
    print( f.read() )

# %% [markdown]
# In Google Colab you can see multiple tabs in the left panel. One of them represents a folder with the files.
#
# If you use Visual Studio Code or Jupyter Notebook, you can see files in the same folder as this lab.

# %% [markdown]
# Let's create a text file

# %%
# open a file in the same directory as the python script, with the mode "w" (write).
f = open("newfile.txt", "w")
# close the opened file
f.close()

# %% [markdown]
# If you look at the created file, it is empty. We did not actually write anything yet. Let's write something.

# %%
f = open("newfile.txt", "w")
f.write("python course at IDMC")
f.close()

# %% [markdown]
# Now let's read (r) this file. The content will be a String and we will print it.

# %%
f = open("newfile.txt", "r")
content_of_the_file = f.read()
f.close()

print(content_of_the_file)

# %% [markdown]
# Let's take a marvelous French poem from Paul Verlaine. The poem is as follows:
# ```
# Les sanglots longs
# Des violons
# De l’automne
# Blessent mon coeur
# D’une langueur
# Monotone.
#
# Tout suffocant
# Et blême, quand
# Sonne l’heure,
# Je me souviens
# Des jours anciens
# Et je pleure
#
# Et je m’en vais
# Au vent mauvais
# Qui m’emporte
# Deçà, delà,
# Pareil à la
# Feuille morte.
# ```

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 5**

# %% [markdown]
# **Write it** EXACTLY as it is in a file. **Then read this file and print** the marvelous poem.

# %%
# CODE ME PLZ 🥺
poem = ["Les sanglots longs", "Des violons, De l’automne", "Blessent mon coeur", "D’une langueur", "Monotone.", "Tout suffocant", "Et blême, quand", "Sonne l’heure,",
        "Je me souviens", "Des jours anciens", "Et je pleure", "Et je m’en vais", "Au vent mauvais", "Qui m’emporte", "Deçà, delà,", "Pareil à la", "Feuille morte."]

f = open("les_sanglots_longs.txt", "w")

for verse in poem:
  f.write(verse + "\n")

f.close()


# now we read the file
f = open("les_sanglots_longs.txt", "r")
content = f.read()
f.close()

print(content)
# Out:
# Les sanglots longs
# Des violons, De l’automne
# Blessent mon coeur
# D’une langueur
# Monotone.
# Tout suffocant
# Et blême, quand
# Sonne l’heure,
# Je me souviens
# Des jours anciens
# Et je pleure
# Et je m’en vais
# Au vent mauvais
# Qui m’emporte
# Deçà, delà,
# Pareil à la
# Feuille morte.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 6**

# %% [markdown]
# There is something missing. **Do it again but using some of these tips:**
# ```python
# # the join function allows to join a list of strings into one string with something between them
# "|".join(my_list)
# ```
#
# ```python
# # the split function will split a string and return a list. In the example below we split by space. But you can split with anything you want.
# "hello you".split(" ")
# ```
#
# ```python
# # this will directly read the lines from a file based on the newlines (returns a list of String)
# lines = f.readlines()
# ```
#
# ```python
# # given a list, this will write each element on a different line
# f.writelines(my_list)
# ```

# %%
# CODE ME PLZ 🥺

# this is an alternative option to do it
poem = """Les sanglots longs
Des violons
De l’automne
Blessent mon coeur
D’une langueur
Monotone.

Tout suffocant
Et blême, quand
Sonne l’heure,
Je me souviens
Des jours anciens
Et je pleure

Et je m’en vais
Au vent mauvais
Qui m’emporte
Deçà, delà,
Pareil à la
Feuille morte."""

f = open("les_sanglots_longs.txt", "w")
f.write(poem)
f.close()

f = open("les_sanglots_longs.txt", "r")
verses = f.read()
f.close()

print(verses)
for verse in verses:
  print(verse)
# Out:
# Les sanglots longs
# Des violons
# De l’automne
# Blessent mon coeur
# D’une langueur
# Monotone.
#
# Tout suffocant
# Et blême, quand
# Sonne l’heure,
# Je me souviens
# Des jours anciens
# Et je pleure
#
# Et je m’en vais
# Au vent mauvais
# Qui m’emporte
# Deçà, delà,
# Pareil à la
# Feuille morte.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 7**

# %% [markdown]
# Now, proceed as follow:
# - Go to the web and search for **two** of your favorite poems (for instance in English: Emily Dickinson, Edgar William Poe, or in French: Arthur Rimbaud, Paul Verlaine).
# - For a poem, put each verse (or line if it is a prose based poem) as elements of a list
# - From the list, create an unique String where each verse is separated by a newline
# - Write the content into a text file
# - Put all these instructions into a function which takes at least one argument: a list of String (verse or lines)
# - Use the function two times to handle write both poems

# %%
# CODE ME PLZ 🥺

# Source: Arthur Rimbaud (IMO the best French Poet) - Départ
depart_arthuRimbaud = ["Assez vu. La vision s'est rencontrée à tous les airs.", "Assez eu. Rumeurs des villes, le soir, et au soleil, et toujours.", "Assez connu. Les arrêts de la vie.", "Ô Rumeurs et Visions !", "Départ dans l'affection et le bruit neufs !"]

# Source: Emily Dickinson - Because I could not stop for Death
stopdeath_emilyDickinson = ["Because I could not stop for Death,", "He kindly stopped for me", "The carriage held but just ourselves", "And immortality."]

def writePoem(verses, poem_title="unknown"):
	"""this function takes verses from a poem and write it into a file"""
	# let's deal with the title, it should not have spaces nor uppercase letters
	title = poem_title.replace(" ", "") # removes spaces
	title = poem_title.lower() # puts the title into lowercase

	# now let's format this file name with added extension (suffix) and poem prefix indication
	outputfilename = f"poem_{title}.txt"
	f = open(outputfilename, "w")
	f.write("\n".join(verses))
	f.close()

# now we can use our function to deal with as many poems as we want
writePoem(depart_arthuRimbaud, poem_title="Depart")
writePoem(stopdeath_emilyDickinson, poem_title="Because I could not stop for Death")

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 8**

# %% [markdown]
# Now read both files and print their content 📃
#
# You should consider doing it with a list and a for loop 😉

# %%
# CODE ME PLZ 🥹
filepaths = ["poem_because i could not stop for death.txt", "poem_depart.txt"]
for fp in filepaths:
	f = open(fp, "r")
	print(f.read())
	f.close()
# Out:
# Because I could not stop for Death,
# He kindly stopped for me
# The carriage held but just ourselves
# And immortality.
# Assez vu. La vision s'est rencontrée à tous les airs.
# Assez eu. Rumeurs des villes, le soir, et au soleil, et toujours.
# Assez connu. Les arrêts de la vie.
# Ô Rumeurs et Visions !
# Départ dans l'affection et le bruit neufs !

# %% [markdown]
# You got your own poem writing function. Convenient isn't it? Did you consider writing a poem of your own?
# Just so you know, recent research works on Natural Language Processing focus on automatic poem generation by an Artificial Intelligence. Do you fill the thrill of knowledge 🥸? Of course, these AI have been made using Python 🥳

# %% [markdown]
# # <font color="teal">**JSON Files**</font>

# %% [markdown]
# Python possess a huge ecosystem with modules for everything. A lot of them are already available, such as the `json` module.
# The `json` allows you to insert a dictionary or a list of dictionaries into a file, and to access it later on.
#
# To use modules you need:
# 1. to import them `import json`
# 2. to look at their documentation: https://docs.python.org/fr/3/library/json.html

# %% [markdown]
# JSON files are a type of file which is made to carry structured data. Dictionaries in Python are mostly similar to JSON files, hence they make a reaaaaaalllly convenient way to handle structured data. JSON files are mainly used to store data converted from dictionarties.
#
# Let's take a look at how it works.

# %% [markdown]
# Create a dict and put it inside a json file:

# %%
# first import the json module
import json

events = {'run': {'message': 'You tried to run but the dog bites you.'}, 'feed': {'message':'You fed the dog with your arm. That hurt!'} }

# the file myFile will auto close when we go back to the previous indentation level (i.e. when we ext the with context)
with open("test.json", "w") as myFile:
    json.dump(events, myFile)

# %%
class Human():
  """
  a basic human
  """
  def __init__(self, name, emotionalstate):
    self.name = name
    self.emotionalstate = emotionalstate

  def speak(self, text):
    """
    docstring
    """
    emoji = "😑"
    if self.emotionalstate == "happy":
      emoji = "😁"
    elif self.emotionalstate == "sad":
      emoji = "😣"
    print(text, emoji)

mehsen = Human("Mehsen", "happy")
max = Human("Max", "sad")
martin = Human("Martin", "dunno")

mehsen.speak("I'm very happy !!!")
max.speak("Hello")
martin.speak("dunno")
# Out:
# I'm very happy !!! 😁
# Hello 😣
# dunno 😑

# %% [markdown]
# Now let us read the json file in a normal way:

# %%
myFile = open('test.json', 'r')
content = myFile.read()
myFile.close()
print(type(content))
print(content)

# %% [markdown]
# The content is a String but we wanted to parsed it as a dictionary.
# To do so we can use the `json` module to open it:

# %%
myFile = open('test.json', 'r')
content = json.load(myFile)
print(type(content))
print(content)
print(content['run'])

# %% [markdown]
# The `json` module can read or write from String representations:

# %%
contentString = '{"type":"I am a string dict, not a real one"}'
content = json.loads( contentString )
myFile.close()
print('from', type(contentString), 'to', type(content))

eventsString = json.dumps( events )
print('from', type(events) , 'to', type(eventsString) )

# %% [markdown]
# What if I have one student represented by the following dictionary:
# ```python
# student = {"firstname": "Thomas", "lastname": "Spiry", "favorite_course": "Python Programming"}
# ```
# We want to store it as a JSON file, which means a file with the .json extension with a dictionary-like content.
#
# Now it is your turn 😁

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 9**

# %% [markdown]
# **Create a dictionary** which contains your firstname, your lastname, your favorite food and how the difficulty range of the Python course from 0 to 10 (yes it is a hidden poll 😛)

# %%
# CODE ME PLZ 🥹

# then let's define a dictionary (whatever the content is)
gaelguibon = {"firstname": "Gaël", "lastname": "Guibon", "favorite_food": "litchis", "difficulty": 5}

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 10**

# %% [markdown]
# **Write this dictionary into a JSON file.**

# %%
# CODE ME PLZ 🥹
import json

f = open("gaelguibon.json", "w")
json.dump(gaelguibon, f)
f.close()

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 11**

# %% [markdown]
# **Read the JSON file** you just created. Then **print both its content and its type**.

# %%
# CODE ME PLZ 🥹

f = open("gaelguibon.json", "r")
loaded_json_content = json.load(f)
f.close()

print("content:", loaded_json_content, "type:", type(loaded_json_content) )
# Out:
# content: {'firstname': 'Gaël', 'lastname': 'Guibon', 'favorite_food': 'litchis', 'difficulty': 5} type: <class 'dict'>

# %% [markdown]
# Wonderful isn't it? 😊
#
#
# No?
#
#
# Think about it: now you can separate your game content (in a JSON file) and the code logic (in the Python file). Yup, this is awesome! you will be able to create complex games without filling overwhelmed!!! 👍

# %% [markdown]
# # <font color="teal">**Recursive Functions**</font>

# %% [markdown]
# A recursive function is a function that called itself in it.
#
# It can serve multiple purposes, and can be quite difficult to grasp. In this section you will see multiple usages for recursive functions. There are many usages so this is not an exhaustive representation of recursivity. However, it is important to understand it. If you do understand recursive functions, then you should not have any issue understanding all the previous notions we tackled in this course. If so, this only means one thing: you did not pratice enough 🙀

# %% [markdown]
# Let's dive into it by creating a function to explore a list of firstnames and put them into uppercase.

# %%
super_students = ["camille", "enzo", "ilan", "pin-xun", "tian"]

def names_to_upper(names, index=0):
	"""
	This function is a recursive function to modify a list of string. It makes each string into an uppercase and goes by one element at a time.
	Arguments:
		names (list): list of string names
		index (int): current index to process. Default value: 0
	"""
	# we modify the element of the list of names at the given index. By using .upper() we put all the characters into uppercase
	names[index] = names[index].upper()
	# now thaht we are done, we can increment the index and put it as the next index to process
	next_index = index + 1
	# we need to verify if the next index exists in the list. A good way is to just check that this index does not exceed the length of the list of names
	if next_index < len(names):
		# if the index exists we first print a message from the function to us (we are the creators of this cute function ;) )
		print(f"Hi my dear creator. I 🤖 just processed the index {index} and will now call myself with the index {next_index}.")
		print(f"The current list is {names}")
		# now we can call the same function, with different arguments: the list of names is update at the current index, and we specify the next index to process
		names_to_upper(names, index=next_index)
	else:
		# if the next index does not exist in the list we print a farewell message from the function. Sayonara cute function, you served us well 😥
		print("Dear creator, I am your function 'names_to_upper' 🤖 and I just finished processing the list you asked me to process. Look at it. Are you proud? 🥹🥹")
		# we directly modify the list of super_students, so that we can use it outside of this function
		super_students = names

# now that our recursive function is defined, we can call it with just one line
names_to_upper(super_students)

# let's print the updated list by our recursive function
print(super_students)
# Out:
# Hi my dear creator. I 🤖 just processed the index 0 and will now call myself with the index 1.
# The current list is ['CAMILLE', 'enzo', 'ilan', 'pin-xun', 'tian']
# Hi my dear creator. I 🤖 just processed the index 1 and will now call myself with the index 2.
# The current list is ['CAMILLE', 'ENZO', 'ilan', 'pin-xun', 'tian']
# Hi my dear creator. I 🤖 just processed the index 2 and will now call myself with the index 3.
# The current list is ['CAMILLE', 'ENZO', 'ILAN', 'pin-xun', 'tian']
# Hi my dear creator. I 🤖 just processed the index 3 and will now call myself with the index 4.
# The current list is ['CAMILLE', 'ENZO', 'ILAN', 'PIN-XUN', 'tian']
# Dear creator, I am your function 'names_to_upper' 🤖 and I just finished processing the list you asked me to process. Look at it. Are you proud? 🥹🥹
# ['CAMILLE', 'ENZO', 'ILAN', 'PIN-XUN', 'TIAN']

# %% [markdown]
# Now, you would protest: "But we could do this really easily with a for loop!". Indeed, the previous recursive function could be simplified as:

# %%
super_students = ["camille", "enzo", "ilan", "pin-xun", "tian"]

def upper_students(names):
	"""
	This function put all the strings into a list of string as uppercase
	Arguments:
		names (list): a list of strings
	"""
	for i in range(len(names)):
		super_students[i] = names[i].upper()

# let's call our function
upper_students(super_students)
# then print the modified list
print(super_students)
# Out:
# ['CAMILLE', 'ENZO', 'ILAN', 'PIN-XUN', 'TIAN']

# %% [markdown]
# Incredible isn't it?
#
# "But then what is the purpose of a recursive function??? 🤔" you may argue.
#
# Do not fret! A recursive function is convenient for different data exploration such as... nested dictionaries !!! 🤭

# %% [markdown]
# Let's consider the following dictionary.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 12**

# %% [markdown]
# Create a recursive function to get the factorial of a number.

# %%
def factorial(n):
  if n <= 1:
    return 1
  else:
    return n * (factorial(n - 1))

print(factorial(5))
# Out:
# 120

# %% [markdown]
# <img height="200px" src="data:image/png;base64,..." />

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 13**

# %% [markdown]
# **Create a recursive function** which searches for an item from a selected brand.

# %%
jewelries = [
        {"brand":"tiffany", "type":"necklace"},
        {"brand":"swarovski", "type":"choker"},
        {"brand":"mejuri", "type":"ring"},
        {"brand":"swarovski", "type":"bracelet"},
        {"brand":"hermès", "type":"earrings"},
        {"brand":"cartier", "type":"necklace"},
        {"brand":"gucci", "type":"ring"},
        {"brand":"bulgari", "type":"choker"},
        {"brand":"tiffany", "type":"ring"},
        {"brand":"cartier", "type":"earrings"},
        {"brand":"mejuri", "type":"bracelet"},
        {"brand":"chanel", "type":"earrings"}
]

def filter_jewelries(type_wanted, elements, filteredElements=[], elementToCheck=None):
        """
        This recursive function iterates through the list of jewelries (elements) one element at a time.
        """
        elementToCheck = elements[0]
        # check if the element contains the desired type
        if elementToCheck["type"] == type_wanted:
                filteredElements.append(elementToCheck)
        # if theere is still some elements, then continue the process by calling the same function but with slightly different parameters
        if len(elements) > 1:
                elements = elements[1:]
                print(filteredElements)
                # calling the same function again will obviously exit this call
                filter_jewelries(type_wanted, elements, filteredElements=filteredElements)
        # this is the exit condition. It is met if there is no elements left into the elements list
        return filteredElements

filtered = filter_jewelries("earrings", jewelries)
print("filtered" + "="*5, filtered, sep="\n")

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 14**

# %% [markdown]
# **Modify the previous recursive function to also consider a target brand.**

# %%
def filter_jewelries(type_wanted, brand_wanted, elements, filteredElements=[], elementToCheck=None):
        """
        This recursive function iterates through the list of jewelries (elements) one element at a time.
        """
        elementToCheck = elements[0]
        # check if the element contains the desired type
        if elementToCheck["type"] == type_wanted and elementToCheck["brand"] == brand_wanted:
                filteredElements.append(elementToCheck)
        # if theere is still some elements, then continue the process by calling the same function but with slightly different parameters
        if len(elements) > 1:
                elements = elements[1:]
                # calling the same function again will obviously exit this call
                filter_jewelries(type_wanted, brand_wanted, elements, filteredElements=filteredElements)
        # this is the exit condition. It is met if there is no elements left into the elements list
        return filteredElements

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 15**

# %% [markdown]
# **Complete the `jewelries` list** with some jewelry that you think is missing.
# Then **call it three times with different targets** 😛

# %%
jewelries.extend([
		{"brand": "hermès", "type": "necklace"}
])
print(filter_jewelries("necklace", "hermès", jewelries))
# Out:
# [{'brand': 'hermès', 'type': 'necklace'}]

# %% [markdown]
# # <font color="teal">**Basic Role Playing Game**</font>

# %% [markdown]
# * Objective: construct a textual role playing game. The game is only text with choices, conditions to verify the choices and player status.
#
# ## <font color="teal">Rules</font>
# * Player advance from a room to another by textually selecting one of the rooms.
# * Player starts with 200 hp (health points)
# * A bad decision costs the player to lose 25 hp.
# * For each actions, display it from a list of Strings
# * Represent data as dictionaries or a big nested dict()
# * Use functions to remove code duplicates and reduce the line numbers
# * Add status and health modification function
# * **Separate the code from the scenario** (external JSON)
# * **Write past choices into an external file**

# %%
# Example with dict  and  ba sic functions and health management
# Placeholders for you to insert requested code
player = dict()
print("Hello Player One, what's your name?")
player['name'] = input()
player['health'] = 200
print("Welcome", player['name'])


def retrieveEventsFromJson(jsonPath):
    """
    This function reads an external json file containing the events infos and returns a dictionary.
    """
    eventsFile = open(jsonPath, 'r') # open the file in 'r' read mode
    eventsDict = json.load(eventsFile) # load the file content into a dict
    eventsFile.close() # do not forget to close the files
    return eventsDict

def writePastChoices( past ):
    """ function that write the past choices to a file .txt """
    pastFile = open('pastChoices.txt', 'a') # we append the choices
    pastFile.write('\n=======\n======\n\n') # append some markers to differenciates the runs
    for p in past: # we iterate over the choices to append them
        pastFile.write(p + '\n') # '\n' means new line
    pastFile.close()

def removeHealth(amount):
    ''' Remove some health from the player. And check if he died. '''
    player['health'] -= amount
    if player['health'] <= 0:
        return False
    else:
        return True

pastChoices = []
events = retrieveEventsFromJson('events.json') # we use the function to get events dict from the json file


def askAction(event, choices):
    '''
    Ask an action from the user. Stay alive while the action is not recognized.
    This is a recursive function 😛
    '''
    choice = ''
    while choice not in choices:
        print('player status', player)
        choice = input()
        try: # using exception instead of list checking
            print(event[choice]['message']) # if this does not work -> exception
            if 'hploss' in event[choice]:
                alive = removeHealth(event[choice]['hploss'])
                if not alive : break
            pastChoices.append(choice)
            if('paths' in event[choice]):
                askAction(event[choice]['paths'], list(event[choice]['paths'].keys()) )
        except:
            print('WRONG : Possible choices', choices )
    return True

print('''Your are in a tiny room. Humidity fills the air but your stomach reminds you that you are very hungry.
        You are in front of two doors. Behind the first one you can hear muffled voices.
        Behind the second one you can smell something intriguing.''')
print('Which door do you choose? Type', list(events.keys())[0], 'for the first room and', list(events.keys())[1],
              'for the second room.')

askAction(events, list(events.keys()) )

print('Here are your remaining stats', player)
writePastChoices( pastChoices ) # we use the function to write the pastChoices into a file.

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO!**

# %% [markdown]
# **Code your game from scratch using functions**
#
# 💡 Tips
# - Use functions when you need to copy paste / repeat some code
# - You need to use all the notions you learned:
#   - variables
#   - list
#   - for loop
#   - while loop
#   - dictionaries
#   - built-in functions
#   - functions you defined
#   - file writing and json
