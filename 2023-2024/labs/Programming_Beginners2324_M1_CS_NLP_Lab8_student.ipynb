# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 8</font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im)
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Student Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The objective of this lab is to practice what we saw during the different lectures and labs. You will pratice pratice and practice again and again. Never stop honing your skill! 😼
#
# This means at the end of this lab you should know :
# 1. (from Lab1): Instructions, Variables, Variable names conventions and comparisons, Arithmetic Operators, Variables types, common errors
# 2. (from Lab2): lists, loops, conditions, String operations
# 3. (from lab3): More List Operations
# 4. (from lab3): Dictionaries
# 6. (from lab4): Functions
# 7. (from lab4): Built-in function usage and import
# 8. (from lab5): Files, jsons, tuples
# 9. (from lab5): Recursive functions
# 10. (from lab6): Object Oriented Programming
# 11. (from lab7): Exceptions
#
# ### <font color="teal">Organization</font>
#
# This lab focuses on the Training Ground to force you to find the correct ways to use the notions you learned.
#
# ### <font color="teal">Evaluation</font>
# This lab will **NOT** take part in your graduation process. But you still have to follow it seriously! 💪

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# - **instructions** : `print()`
# - **basic operators** : logic (`and or`), math (`+ = - /`), membership (`in` `not in`)
# - **variables** : `name = city` `city = 'Nancy'`
# - **types concepts and basics** and conversion : `type()` `str()` `bool()` `int()` `float()` `list()`
# - **list operations**:
#   - `append(x)` : add an element at the end of the list
#   - `extend([x, y, z])` : add all these elements at the end of the list
#   - `pop([index])` : delete and return the last element of the list (or given indexes)
#   - `remove(x)` : remove first element with value x
#   - `index(x)` : return the index of the first element with value x
#   - `count(x)` : return the number of occurrences for x
#   - `sort()` : sort the list.
#   - `reverse()` : reverse the list order
#   - `insert(index, value)` : insert an element into a target index
# - **conditions** :
#   - ```python
#     if condition1:
#       print("if condition1 is true, print this")
#     elif condition2:
#       print("if condition 1 is not true but then condition2 is true")
#     else:
#       print("sinon")
#     ```
# - **loops** :
#   - ```python
#     for element in elements:
#       print(element)
#     ```
#   - ```python
#     for i in range(5):
#       print(i)
#     ```
#   - ```python
#       while bubbletea_exists and money>=5:
#         print("enjoy some bubble tea")
#     ```
# - **dictionaries** :
#   - ```python
#     data = {"name":"gael"}
#     print(data['name'])
#     ```
# - **functions** :
#   - ```python
#     def say_hello(name):
#       print(f"Hello {name}! :D")
#   ```
# - **files** :
#   - ```python
#     with open("subdir/myfile.txt", "r") as f:
#       print(f.read())
#   ```
#   - ```python
#     with open("subdir/myfile.txt", "w") as f:
#       f.write("hello")
#   ```
# - **json files** :
#   - ```python
#     with open("subdir/file.json", "r") as f:
#       dico = json.load(f)
#   ```
#   - ```python
#     with open("subdir/file.json", "w") as f:
#       dico = {"k":"v"}
#       json.dump(dico, f)
#   ```
# - **object oriented programming**:
#   - ```python
#     class CutieCat():
#       def __init__(self, name_param, age_param):
#         """ the constructor method of the CutieCat class"""
#         self.property_name = name_param
#         self.property_age = age_param
#       def speak(self, speech):
#         """ this is a method to make it speak. Even if it takes the speech param
#         it will still output "Meoowww", because it is a cat, it can't speak!
#         """
#         return "Meoooww"
#
#     # now we can instanciate one CutieCat named kitty
#     aCutieCat = CutieCat("kitty", 5)
#     print( aCutieCat.speak("hello") )
#     # it outputs "Meoooww"
#   ```
#
# - **exceptions**:
#   - ```python
#   try:
#     # do something
#   except:
#     # do something else
#   ```

# %% [markdown]
# # <font color="teal">**Training Ground**</font>

# %% [markdown]
# <img src="data:image/png;base64,..." height="200px" />

# %% [markdown]
# In this course you tackled many notions and tried to make the best use of them while creating a game.
#
# Now, let's stop learning new programming notions and simply train 😤
#
# Keep in mind that what you learned can serve to do maaaaaaany things! To be fair, everyday programming is mainly using basic notions! Sooooo, the next issue is **HOW** to use the notions efficiently.
#
# Let's do some *cute* exercises 😛
#
# Even though these exercises are such *cuties*, you are dangerously free to solve them as you see fit! So good luck 🤣 and make use of the different notions.

# %% [markdown]
# <img src="data:image/png;base64,..." height="200px" />

# %% [markdown]
# <img height="200px" src="data:image/png;base64,..." />

# %%
# let's download all the data
# you can see the pokemon file is now humanly readable to help you use it ;)
! wget https://gitlab.com/gguibon/idmc-storage/-/raw/main/heros.json.zip
! unzip heros.json.zip
! wget https://gitlab.com/gguibon/idmc-storage/-/raw/main/pokemons.json

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 1**

# %% [markdown]
# Open the two json files **using one single function** and put their content into a variable

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# For this lab you will only use the heros data 😜

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 2**

# %% [markdown]
# Print the keys of one of the hero's dictionary

# %%
# CODE ME PLZ 🥺
# Out:
# dict_keys(['name', 'real_name', 'full_name', 'overall_score', 'history_text', 'powers_text', 'intelligence_score', 'strength_score', 'speed_score', 'durability_score', 'power_score', 'combat_score', 'superpowers', 'alter_egos', 'aliases', 'place_of_birth', 'first_appearance', 'creator', 'alignment', 'occupation', 'base', 'teams', 'relatives', 'gender', 'type_race', 'height', 'weight', 'eye_color', 'hair_color', 'skin_color', 'img', 'has_electrokinesis', 'has_energy_constructs', 'has_mind_control_resistance', 'has_matter_manipulation', 'has_telepathy_resistance', 'has_mind_control', 'has_enhanced_hearing', 'has_dimensional_travel', 'has_element_control', 'has_size_changing', 'has_fire_resistance', 'has_fire_control', 'has_dexterity', 'has_reality_warping', 'has_illusions', 'has_energy_beams', 'has_peak_human_condition', 'has_shapeshifting', 'has_heat_resistance', 'has_jump', 'has_self-sustenance', 'has_energy_absorption', 'has_cold_resistance', 'has_magic', 'has_telekinesis', 'has_toxin_and_disease_resistance', 'has_telepathy', 'has_regeneration', 'has_immortality', 'has_teleportation', 'has_force_fields', 'has_energy_manipulation', 'has_endurance', 'has_longevity', 'has_weapon-based_powers', 'has_energy_blasts', 'has_enhanced_senses', 'has_invulnerability', 'has_stealth', 'has_marksmanship', 'has_flight', 'has_accelerated_healing', 'has_weapons_master', 'has_intelligence', 'has_reflexes', 'has_super_speed', 'has_durability', 'has_stamina', 'has_agility', 'has_super_strength'])

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 3**

# %% [markdown]
# Create a function to get a hero by name.

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 4**

# %% [markdown]
# Use it to retrieve the hero named "Poison Ivy"

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 5**

# %% [markdown]
# Create a function to retrieve all heros which contains some String value in their name
#
# (Beware! There is a trap 😼)

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 6**

# %% [markdown]
# Use this fonction to get all the heros which contains "Poison" in their name.

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 7**

# %% [markdown]
# Create a function to retrieve the strongest hero(s) based on the following global score: the sum of the different hero scores multiplied by the number of superpowers the hero possesses.
#
# Tips 💡
# - you could create a function dedicated to the global score calculation

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# ## <font color="teal">Object Oriented version 😃</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 8**

# %% [markdown]
# Let's do the same, but in an Object Oriented way!
#
# Create a class to represent a hero (*without getters and setters to gain some time* 😏).
#
# Just focus on the main heros' properties:
#
# - name
# - intelligence_score, strength_score, combat_score
# - superpowers

# %% [markdown]
# To this class, add a method to retrieve the number of superpowers.

# %%
class Hero():
  # CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 9**

# %% [markdown]
# Create an instance of the class Hero by using the first hero's dictionary.
#
# The use it's method to get its calculated score.

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 10**

# %% [markdown]
# - Create another class named `Superheros`
# - In this class integrate the method to retrieve a hero by its name
# - In this class integrate the method to get the strongest hero(s)

# %%
class Superheros():
  # CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 11**

# %% [markdown]
# Use this `Superheros` class to retrieve a hero named "Cypher". Print it as a dictionary.

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 12**

# %% [markdown]
# Use this `Superheros` class to retrieve all the strongest hero(s).
#
# Then print only the name(s) of the strongest hero(s).

# %%
# CODE ME PLZ 🥺
# Out:
# Black Alice

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 13**

# %% [markdown]
# If you are done. Add a method to the `Superheros` class to retrieve the total number of different superpowers accross the whole dataset.

# %%
# CODE ME PLZ 🥺

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 14**

# %% [markdown]
# How many different superpowers are there?

# %%
# CODE ME PLZ 🥺
