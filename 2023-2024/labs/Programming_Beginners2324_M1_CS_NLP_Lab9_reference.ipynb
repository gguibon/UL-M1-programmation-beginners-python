# %% [markdown]
# <center><img src="data:image/png;base64,..."/><img src="data:image/png;base64,..." /></center>

# %% [markdown]
# <h1><center><strong><font color="Teal">CM EC2: A Programmation Beginners, Python<br/> Master Cognitive Sciences and Natural Language Processing <br/> Lab 9</font></strong></center></h1>
#
#
# <center>
# <h3><a href="https://gguibon.github.io/">Gaël Guibon</a></h3>
# <email>gael.guibon@univ-lorraine.fr</email>
# <h4><a href="https://fr.linkedin.com/in/nasser-eddine-monir-20916a174">Nasser-Eddine Monir</a></h4>
# <email>nasser-eddine.monir@inria.fr</email>
# <br/>
# Year 2023-2024
#
# Original Content
#
# Some parts are inspired from:
# [Clement Plank's IM Course](https://github.com/clement-plancq/python-im)
#
# Licenced under Affero GNU3
# </center>

# %% [markdown]
# <center><h3><center><font color="green"><strong>Reference Version</strong></font></center></h3><img height="200px" src="data:image/png;base64,..."/></center>

# %% [markdown]
# ------------------------

# %% [markdown]
# # <font color="teal">**Usage (a.k.a. README)**</font>

# %% [markdown]
# This is a python notebook that we will use for the lab today. It is hosted by Google Colab to make it easy to share. You should be able to edit it, but your edits won't be saved, so I don't recommend it.
#
#
# In order to work with it and answer the questions, you can either use it in Google Colab, download it and use it in VSCode (or other IDE) or Jupyter Notebook.
#
# **Usage in Google Colab.** If you own a Google account, you can upload a copy of this file and edit it with saves. To do so got to "File" > "Save a copy in Drive". Don't forget to use the interactive Table of Content on the left panel.
#
# **Local Usage.** You can download it either as a jupyter notebook (.ipynb) or as a python programme (.py) using the File>Download menu (Fichier>Télécharger in French). We recommend that you download it as a Jupyter Notebook to work on and edit on your own laptop.

# %% [markdown]
# ## <font color="teal">"Quality of Life" Tips</font>

# %% [markdown]
# - To better understand when you need to do something, please for the ![programming(3).png](data:image/png;base64,...) **TODO!** marks sprinkled across the lab!

# %% [markdown]
# - Run the small pieces of code (named Code Cells) below to see what they do (in Jupyter Notebook or Google Colab, press the small \"play\" button on the left, or press ctrl+enter in the code box)
# - On Google Colab and VSCode, you can fold and unfold section and subsections to better display the notebook. Try to click on the arrow of this '"Quality of Life" Tips' section as below:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## <font color="teal">Install local python environnement</font>
# At home you may want to use Python locally. Here are the steps:
# 1. Download the latest Python (Python3 not 2) from here: [https://www.python.org/downloads/](https://www.python.org/downloads/)
# 2. Install it (if you are using Ubuntu 16.04 you already have Python installed)
#
# Start using it:
# - Open terminal(unix/mac) or CommandLine(windows), type `python` to start an interactive python environnement
# - Create a file named `my_super_program.py` and type `print('hello')` inside. Execute this file by typing `python3 my_super_program.py`.
#
# To code you may need an IDE for smoother coding. I would suggest [Visual Studio Code](https://code.visualstudio.com/Download).

# %% [markdown]
# # <font color="teal">**Objectives**</font>

# %% [markdown]
# The objective of this lab is to practice what we saw during the different lectures and labs. You will pratice pratice and practice again and again. Never stop honing your skill! 😼
#
# This means at the end of this lab you should know :
# 1. (from Lab1): Instructions, Variables, Variable names conventions and comparisons, Arithmetic Operators, Variables types, common errors
# 2. (from Lab2): lists, loops, conditions, String operations
# 3. (from lab3): More List Operations
# 4. (from lab3): Dictionaries
# 6. (from lab4): Functions
# 7. (from lab4): Built-in function usage and import
# 8. (from lab5): Files, jsons, tuples
# 9. (from lab5): Recursive functions
# 10. (from lab6): Object Oriented Programming
# 11. (from lab7): Exceptions
#
# ### <font color="teal">Organization</font>
#
# This lab follows the same organization as last lab: mainly Training Ground and some Fix Fest.
#
# ### <font color="teal">Evaluation</font>
# This lab will **NOT** take part in your graduation process. But you still have to follow it seriously! 💪

# %% [markdown]
# # <font color="teal">**Reminders**</font>

# %% [markdown]
# - **instructions** : `print()`
# - **basic operators** : logic (`and or`), math (`+ = - /`), membership (`in` `not in`)
# - **variables** : `name = city` `city = 'Nancy'`
# - **types concepts and basics** and conversion : `type()` `str()` `bool()` `int()` `float()` `list()`
# - **list operations**:
#   - `append(x)` : add an element at the end of the list
#   - `extend([x, y, z])` : add all these elements at the end of the list
#   - `pop([index])` : delete and return the last element of the list (or given indexes)
#   - `remove(x)` : remove first element with value x
#   - `index(x)` : return the index of the first element with value x
#   - `count(x)` : return the number of occurrences for x
#   - `sort()` : sort the list.
#   - `reverse()` : reverse the list order
#   - `insert(index, value)` : insert an element into a target index
# - **conditions** :
#   - ```python
#     if condition1:
#       print("if condition1 is true, print this")
#     elif condition2:
#       print("if condition 1 is not true but then condition2 is true")
#     else:
#       print("sinon")
#     ```
# - **loops** :
#   - ```python
#     for element in elements:
#       print(element)
#     ```
#   - ```python
#     for i in range(5):
#       print(i)
#     ```
#   - ```python
#       while bubbletea_exists and money>=5:
#         print("enjoy some bubble tea")
#     ```
# - **dictionaries** :
#   - ```python
#     data = {"name":"gael"}
#     print(data['name'])
#     ```
# - **functions** :
#   - ```python
#     def say_hello(name):
#       print(f"Hello {name}! :D")
#   ```
# - **files** :
#   - ```python
#     with open("subdir/myfile.txt", "r") as f:
#       print(f.read())
#   ```
#   - ```python
#     with open("subdir/myfile.txt", "w") as f:
#       f.write("hello")
#   ```
# - **json files** :
#   - ```python
#     with open("subdir/file.json", "r") as f:
#       dico = json.load(f)
#   ```
#   - ```python
#     with open("subdir/file.json", "w") as f:
#       dico = {"k":"v"}
#       json.dump(dico, f)
#   ```
# - **object oriented programming**:
#   - ```python
#     class CutieCat():
#       def __init__(self, name_param, age_param):
#         """ the constructor method of the CutieCat class"""
#         self.property_name = name_param
#         self.property_age = age_param
#       def speak(self, speech):
#         """ this is a method to make it speak. Even if it takes the speech param
#         it will still output "Meoowww", because it is a cat, it can't speak!
#         """
#         return "Meoooww"
#
#     # now we can instanciate one CutieCat named kitty
#     aCutieCat = CutieCat("kitty", 5)
#     print( aCutieCat.speak("hello") )
#     # it outputs "Meoooww"
#   ```
#
# - **exceptions**:
#   - ```python
#   try:
#     # do something
#   except:
#     # do something else
#   ```

# %% [markdown]
# # <font color="teal">**Training Reminders**</font>

# %% [markdown]
# This lab will focus on training and checking most of the notions we tackled. (You should be able to do everything here, otherwise this means you are not yet ready for the exam 😵‍💫)
#
# 🇫🇷 Ce TD est dédié à la vérification de la plupart des notions que nous avons abordées dans ce cours. Vous devriez être capable de tout faire, autrement il s'agit d'un signe que vous n'êtes pas prêt(e) pour l'examen 😵‍💫

# %% [markdown]
# ## <font color="teal">Variables</font>

# %% [markdown]
# Yup, let's start from the beginning: variables 😃
#
# 🇫🇷 Commençons par le début : les variables 😃

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 1**

# %% [markdown]
# Put your firstname in lowercase in a variable then print it
#
# 🇫🇷 Mettez votre prénom en minuscules dans une variable puis affichez la

# %%
firstname = "gaël"
print(firstname)
# Out:
# gaël

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 2**

# %% [markdown]
# Put your lastname in lowercase in a variable then print it
#
# 🇫🇷 Mettez votre nom de famille en minuscules dans une variable puis affichez la

# %%
lastname = "guibon"
print(lastname)
# Out:
# guibon

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 3**

# %% [markdown]
# Concatenate your firstname and your lastname in another variable both with their first letter as a capital letter. And separated by a space.
#
# Remember, there is one way to concatenate String values (and multiple to format String values).
#
# 🇫🇷 Concaténez votre prénom et votre nom de famille dans une autre variable. Les deux devant cette fois-ci commencer par une majuscule et être séparés par un espace.
#
# Pour rappel, il y a une façon de concaténer des valeurs String (et aussi plusieurs façons de les formatter).

# %%
fullname = f"{firstname[0].upper() + firstname[1:]} {lastname[0].upper() + lastname[1:]}"
print(fullname)
# Out:
# Gaël Guibon

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 4**

# %% [markdown]
# Put your age in a variable
#
# 🇫🇷 Mettez votre âge dans une variable

# %%
age = 35
print(age)
# Out:
# 35

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 5**

# %% [markdown]
# Print the type of the variable which contains your age
#
# 🇫🇷 Affichez le type de la variable qui contient votre âge

# %%
print( type(age) )
# Out:
# <class 'int'>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 6**

# %% [markdown]
# Create two boolean variables: one to store if you are in the NLP master, another one to store if you are in the Cognitive Science master.
#
# 🇫🇷 Créez deux variables booléennes: une pour indiquer si vous suivez le master TAL, une autre pour indiquer si vous suivez le master sciences co.

# %%
nlp = True
cs = False

# %% [markdown]
# ## <font color="teal">Lists & Loops</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 7**

# %% [markdown]
# Put all those variables into a list
#
# 🇫🇷 Mettez toutes ces variables dans une liste

# %%
mydata = [firstname, lastname, fullname, age, nlp, cs]
print(mydata)
# Out:
# ['gaël', 'guibon', 'Gaël Guibon', 35, True, False]

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 8**

# %% [markdown]
# Print the length of the list
#
# 🇫🇷 Affichez la longueur de la liste

# %%
print( len(mydata) )
# Out:
# 6

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 9**

# %% [markdown]
# Create a String variable which contains all these variable content as one String value. Each content should be separated by a vertical bar ```|```
#
# You would need the `.join()` method
#
# 🇫🇷 Créez une variable String qui contient tous les contenus des variables précédentes en une seule et même String (chaîne de caractères -- autrement dit, du texte). Chaque contenu doit être séparé par une barre verticale ```|```
#
# Vous devriez avoir besoin de la méthode `.join()`

# %%
mylist = []
for element in mydata:
  mylist.append(str(element))
print(mylist)

mydatastr = "|".join(mylist)
print(mydatastr)
# Out:
# ['gaël', 'guibon', 'Gaël Guibon', '35', 'True', 'False']
# gaël|guibon|Gaël Guibon|35|True|False

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 10**

# %% [markdown]
# Using the previous String variable, transform it again into a list of String.
# You would need the `.split()` method.
#
# 🇫🇷 À l'aide de la variable String précédemment créée, transformez la en une liste de String. Vous devriez avoir besoin de la méthode `.split()`

# %%
mydatastr_list = mydatastr.split("|")
print(mydatastr_list)
# Out:
# ['gaël', 'guibon', 'Gaël Guibon', '35', 'True', 'False']

# %% [markdown]
# ## <font color="teal">Dictionaries & Loops</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 11**

# %% [markdown]
# Using this last list, put all the values into a dictionary. You need to use the given list of keys.
#
# You can use `zip()` or the indices of list elements.
#
# 🇫🇷 En utilisant la dernière liste créée, mettez toutes ses valeurs dans un dictionaire. Attention, ce n'est pas si simple, vous devez utiliser la liste de clés ci-dessous.
#
# Vous pouvez utiliser la fonction `zip()` ou les indices des éléments de la liste.

# %%
target_keys = ['firstname', 'lastname', 'fullname', 'age', 'nlp', 'cs']

# naive version mixing multiple notions :)
mydico = {}
for key, element in zip(target_keys, mydatastr_list):
	try:
		mydico[ key ] = int(element)
		continue
	except: pass

	if key in ['nlp', 'cs']:
		mydico[key] = bool(element)
	else:
		mydico[key] = element

print(mydico)
# Out:
# {'firstname': 'gaël', 'lastname': 'guibon', 'fullname': 'Gaël Guibon', 'age': 35, 'nlp': True, 'cs': True}

# %% [markdown]
# ## <font color="teal">Files</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 12**

# %% [markdown]
# Create a file with a short bio (one sentence).
#
# For example: "Hello I'm Gaël and I loooove litchis so much! (But I do prefer Pythons) 🤭"
#
# The filename should be your fullname without space (`.replace()`) and with added text file extension (usually ".txt").
#
# 🇫🇷 Créez un fichier avec une brève biographie (une seule phrase).
#
# Par exemple: "Salut salut~ moi c'est Gaël et j'adooore les litchis ! (Mais je préfère les Pythons) 🤭"
#
# Le nom du fichier doit être votre nom complet sans espace (`.replace()`) avec l'extension de fichier ajoutée (habituellement l'extension est ".txt" pour indiquer du texte)

# %%
with open("%s.txt" % (fullname.replace(" ", "")), 'w') as f:
	f.write("Hello my name is Gaël! I love litchis but I do prefer Pythons 😂")

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 13**

# %% [markdown]
# Open the file manually :) (using your mouse and file explorer 😱)
#
# 🇫🇷 Ouvrez le fichier manuellement :) (oui oui, avec votre souris et votre explorateur de fichier 😱)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 14**

# %% [markdown]
# Read the file using Python and put its content into a variable `shortbio`.
#
# Then print this variable.
#
# 🇫🇷 Lisez le fichier avec Python cette fois-ci. Et mettez son contenu dans une variable `shortbio` (ce qui signifie "courtebiography").
#
# Puis affichez cette variable.

# %%
with open("%s.txt" % (fullname.replace(" ", "")), 'r') as f:
	shortbio = f.read()

print(shortbio)
# Out:
# Hello my name is Gaël! I love litchis but I do prefer Pythons 😂

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 15**

# %% [markdown]
# Save your previous dictionary with your data (name, age, etc.) into a JSON file `mydata.json`.
#
# 🇫🇷 Sauvegardez votre précédent dictionnaire, celuis qui contient vos données (prénom, nom, âge, etc.). Sauvegardez le dans un fichier JSON `mydata.json` (ce qui signifie "mesdonnées.json").

# %%
import json
with open("mydata.json", "w") as f:
	json.dump(mydico, f)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 16**

# %% [markdown]
# Open your JSON file manually using your file explorer. Open it with your browser for instance (firefox, chrome, etc.)
#
# 🇫🇷 Ouvrez votre fichier JSON manuellement avec votre explorateur de fichier. Ouvrez le avec votre navigateur internet par exemple (Firefox, Chrome, etc.)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 17**

# %% [markdown]
# Open your JSON file using Python and put its content into a variable named `mydata`
#
# 🇫🇷 Ouvrez votre fichier JSON à l'aide de Python et mettez son contenu dans une variable `mydata` (ce qui signifie "mesdonnées")

# %%
with open("mydata.json", "r") as f:
	mydata = json.load(f)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 18**

# %% [markdown]
# Print the type of the data in `mydata` and print the type of the value associated with the `age` key.
#
# 🇫🇷 Affichez le type du contenu de `mydata`et affichez le type de la valeur associées à la clé `age`.

# %%
print( type(mydata) )
print( type(mydata["age"]) )
# Out:
# <class 'dict'>
# <class 'int'>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 19**

# %% [markdown]
# Add the shortbio in a dedicated key in the JSON file and save it.
#
# 🇫🇷 Ajoutez la courte biographie dans une clé dédiée dans votre fichier JSON et sauvegardez le.

# %%
mydata["bio"] = shortbio
with open("mydata.json", "w") as f:
	json.dump(mydata, f)

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 20**

# %% [markdown]
# Now verify if the new content is ok by opening it again and printing its content.
#
# 🇫🇷 Désormais, vérifiez si le nouveau contenu est bon en ouvrant de nouveau votre fichier puis en affichant son contenu.

# %%
with open("mydata.json", "r") as f:
	print(json.load(f))
# Out:
# {'firstname': 'gaël', 'lastname': 'guibon', 'fullname': 'Gaël Guibon', 'age': 35, 'nlp': True, 'cs': True, 'bio': 'Hello my name is Gaël! I love litchis but I do prefer Pythons 😂'}

# %% [markdown]
# ## <font color="teal">Functions</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 21**

# %% [markdown]
# Create a function named `moody()` which returns a random emoji among the following ones:
# ```python
# emojis = ['😃', '🥹', '😭', '😖', '😤', '🥵', '😱']
# ```
#
# Don't forget to use `random.choice()`
#
# 🇫🇷 Créez une fonction nommée `moody()` qui retourne un emoji aléatoire parmi les emojis suivants :
# ```python
# emojis = ['😃', '🥹', '😭', '😖', '😤', '🥵', '😱']
# ```
#
# N'oubliez pas d'utiliser `random.choice()`

# %%
import random

def moody():
	""" a fonction to randomly print a moooooood  """
	emojis = ['😃', '🥹', '😭', '😖', '😤', '🥵', '😱']
	random_emoji = random.choice(emojis)
	return random_emoji

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 22**

# %% [markdown]
# Call the created function to put its output into a variable named `mymood`
#
# 🇫🇷 Appelez cette fonction pour prendre sa sortie et l'assigner à une variable nommée `mymood` (ce qui signifie "mon humeur")

# %%
mymood = moody()

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 23**

# %% [markdown]
# Create another function named `feedback` which accepts an emoji as one positional argument. This function will print a textual feedback given the emoji. For sad ones it will print `"oh noooo!!!"` for instance
#
# 🇫🇷 Créez une autre fonction nommée `feedback` (ce qui signifie "retour" dans le sens d'une remarque constructive) qui prend un emoji en argument positionnel. Cette fonction affiche un retour textuel en fonction de l'emoji donné en argument. Par exemple, pour les emojis tristes, elle affichera `"Oh Noooooon!!!"`

# %%
def feedback(emoji):
	""" function to print a feedback given the emoji"""
	sad = emoji in ['🥹', '😭', '😖']
	fear = emoji in ['😱']
	joy = emoji in ['😃']
	tired = emoji in ['🥵']
	angry = emoji in ['😤']

	if sad: print("oh nooo!!!")
	elif fear: print("it's ok don't be afraid")
	elif joy: print("yup that's the way to go~")
	elif tired: print("keep pushing")
	elif angry: print("don't hit me!")
	else: print("what is it?")

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 24**

# %% [markdown]
# Call the `feedback` function with the random emoji `mymood` as an argument.
#
# 🇫🇷 Appelez la fonction `feedback` avec un emoji aléatoire donné en argument.

# %%
feedback( mymood )
# Out:
# keep pushing

# %% [markdown]
# ## <font color="teal"> Object Oriented Programming</font>

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 25**

# %% [markdown]
# Create a class `Person` to represent a person given the keys from the `mydata.json` file.
#
# - The constructor should accept a dictionary (the one from the json file) and map it's keys as attributes
# - Add a method `rejuvenate` which accepts an optional argument to change the default amount of years to rejuvenate from. This method should change the Person's age and finally print a joyful message. For instance: "Youhou Gaël is 15 years younger! 😇 (now 20 years old)".
#
# Of course, it should be IMPOSSIBLE for a person to be less than one year's old.
#
# And of course, you should not be able to rejuvenate with a value that equals zero or below.
#
# 🇫🇷 Créez une classe `Person` (ce qui signifie "Personne") pour représenter une personne en fonction des clés issues de votre fichier `mydata.json`.
#
# - Le constructeur doit accepter en argument un dictionnaire (celui issu du fichier json) et utiliser ses clés comme attributs
# - Ajoutez une méthode `rejuvenate` (ce qui signifie "rajeunir") qui prend un argument optionnel pour changer le nombre d'années à rajeunir. Cette méthode doit changer l'âge de la Person (personne) et enfin afficher un joyeux message, tel que : "Youhou Gaël est plus jeune de 15 années! 😇 (désormais agé de 20 ans)".
#
# Bien entendu, il doit être IMPOSSIBLE pour une personne d'avoir moins de 1 an.
#
# Et bien sûr, vous ne devriez pas pouvoir rajeunir de 0 années, ni même de moins que cela.

# %%
class Person():
	"""
	class which represents a person
	"""
	def __init__(self, data):
		self.firstname = data["firstname"]
		self.lastname = data["lastname"]
		self.fullname = data["fullname"]
		self.age = data["age"]
		self.nlp = data["nlp"]
		self.cs = data["cs"]

	def rejuvenate(self, years=1):
		"""
		ancien legendary method also called "Cure de jouvence" 🤪
		"""
		if years >= 0:
			self.age -= years
			if self.age < 1:
				self.age = 1
			print(f"Youhou {self.firstname} is {years} years younger! 😇 (now {self.age} years old)")

# %% [markdown]
# #### ![programming(3).png](data:image/png;base64,...) **TODO 26**

# %% [markdown]
# Use your `Person` class to represent your data from the json file in a new instance.
#
# Then use the legendary `rejuvenate` method to be **x** years younger.
#
# 🇫🇷 Utilisez votre classe `Person` pour représenter vos données issues du fichier json dans une nouvelle instance.
#
# Puis utilisez la légendaire cure de jouvence (la méthode `rejuvenate`) pour être **x** années plus jeune.

# %%
moi = Person(mydata)
moi.rejuvenate(15)
# Out:
# Youhou gaël is 15 years younger! 😇 (now 20 years old)

# %% [markdown]
# Congratz you finished this lab! Now go back to labs 7 and 8 to see more advanced usage linked to a JSON file. This 3 labs will help you train for the exam.
#
# 🇫🇷 Bravo vous avez fini ce TD ! Maintenant reprenez les deux derniers TD (7 et 8) pour revoir l'utilisation plus avancée pour un fichier JSON. Ces trois TDs sont là pour vous aider à préparer l'examen.
